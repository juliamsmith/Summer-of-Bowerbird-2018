# %%
#Key
#Notes- Paramters contain underscores, while functions don't
#SB: Stay at bower
#FG: Foraging
#MT: Maraud travel (travel to rival's bower)
#MA: Maraud action (destroy bower if absent, have antagonistic interaction in present)
#MR: Maraud return (return to own bower)
#RB: Repair own bower
#MT_vs_FG: the probability of next transition away from SB being to MT (otherwise it would be to FG)
#a=-1: denotes a staying at bower action on ticket
#a=-2: denotes a foraging action on ticket
#a=-3: denotes a female visiting action on a ticket
#a=-4: denotes travel to another male's bower
#a=-5: denotes marauding of another male's bower
#a=-6: denotes returning from another male's bower
#a=-7: denotes a bower repair action on a ticket
#target: the male/node an action is preformed on. For maurading, the target is the bird under potential attack. For mating, target is male being mated with. For other activities other then maurading and mating, owner and target are the same.
#owner: The male or female actively performing an action. For mating, the female is the owner. For all other activities, the owner is male.
#networkwriter: generates network where everybird is connected
#addtotimeline: adds tickets to timeline
#travel_times_linear_p: generates a matrix that contains the probabilities of travelling to a given a bower 
#if the relationship between distance and travel preference is linear
#improb: The probability of traveling improb_distance or less
#improb_distance: The distance at which there is only a (1-improb)% chance of choosing to travel
#lamb: lambda calculated by solving improb=1-numpy.exp(-lamb*improb_distance)
#bower_states: options are 1 (bower intact) and 0 (bower destroyed-will never be the case when all guarders) and another value for time that mating will end (assuming mating is happening)
#male_states: options are [leave_time, leave_action, SB_timeholder] (male present at bower) and 0 (male absent from bower)
#fitness_states: keeps track of number of matings a given male has had
#t: time
#nodes: total number of male bowerbirds in the network
#node_dist: the node by nde matrix with distances between each node
#node_graph: matrix with individuals 1 through nodes numbered by going through each row
#tau: Length of time an activity takes. If a foraging ticket has a tau of 0.5 and occurs at t=1, then the bird is foraging for 30 minutes, at which point a SB activity will start (at t=1.5).
#t_court: the amount of time it takes a female to court+mate with a male, generated from a normal distribution


import math
import random
import numpy as numpy
import matplotlib.pyplot as plt


#Parameters:
t=0.0 #start at time 0
t_max=12#12*4*30 #2 months in hrs (assume no nights so 12 hr = 1 day)
timeholder=0
timeline=[] #initialize the timeline
discards=[] #where we put the old version of tickets that get over-written/moved
#We've moved away from using these params with expovariate (how we handle FV is still TBD)
#So THE BELOW 3 SHOULD BE COMMENTED OUT (but rn we don't want the handler funcs to yell at us)
FV_param=[1, t_max/2] #5days, tmax/3 #0.2 #nodes/0.19 #totally random
FG_param=3 #larger values lead to foraging ending earlier, because taus are smaller
SB_param=1.5 #larger values lead to bowerstay ending earlier, because taus are smaller
RB_param=2 #made up -- takes 30mins (every time -- no distribution) to repair bower
MA_param=.1 #made up -- takes 6mins (every time -- no distribution) to maraud bower
MT_vs_FG=.05 #compared 20 feedings/day to .1 maraudings/hr
nodes=4
bower_states=[1]*nodes
male_states=[0]*nodes #start at foraging now
mating_states=[0]*nodes
fitness_states=[0]*nodes
success_rates=1
success_times=[] #going to change this to be a vector of times when the female leaves (at this point, sucessful mating has occured)
recents_list=[]
max_visits=6 #STEEEEVEEEE
bird_speed=12*3600 #m/hr (12m/s)
d=150.0




# makes a ticket
def ticketgenerator(tau,t, o, a, targ, t2):
    ticket={
        'tau': tau,
        'time': t,
        'owner': o,
        'action': a,
        'target': targ,
        'origin': t2 
    }
    return ticket;

#writes the edges to a network of n birds where everyone is connected to everyone else 
def networkwriter(n):
    connect=[0]*n
    for i in range(0, n): 
        a=list(range(n)) #generating a list that goes from 0 to n-1
        a.remove(i) #individual removes themselves from the network
        connect[i]=a #corresponds to the list of people person i is linked to
    return connect; #returns a list of lists with all the connections in the network


# function for determining the next time based on our rate parameters
def nexttau(action):
    x=-1
    while x<=0:
        switcher = { #NOTE: used abs
            -1: numpy.random.normal(loc=.1583, scale=.09755, size=1)[0], #choose when to leave bower (generate a tau for bower stay)
            -2: numpy.random.gamma(shape=1.5, scale=5, size=1)[0]/60, #choose when to stop foraging (generate a tau for foraging)
            -3: numpy.random.uniform(FV_param[0], FV_param[1]), #FV_param... totally arbitrary so we should think about it
            -5: MA_param, #in the future we'll do something with it
            -7: RB_param #in the future we'll do something with it 
        }
        x=switcher.get(action)
    return x
    

#adds new tickets to timeline -- Stefano, any more efficient suggestions for keeping timeline in order?
def addtotimeline(tic, timeline):
    if not timeline:
        timeline.append(tic)
    else:
        ind=len(timeline)-1
        end=0
        while (tic['time']<timeline[ind]['time'] and end==0): #moves backwards until it finds where to place the ticket based on the listed times
            ind=ind-1 
            if(ind<0):
                end=1
        ind=ind+1
        timeline.insert(ind, tic)
        
#Stay at bower ticket handler. Ticket is read, and male state changes to at bower. Can generate repair bower, foraging, or maurad travel ticket.
def SBtickethandler(SB_tic, timeline, t_max, male_states, MT_vs_FG, visit_preferences, travel_times):
    ow=SB_tic['owner'] 
    if male_states[ow]!=0: #because any male who is at his bower was last repairing his bower (not coming from FG or MR) 
        bower_states[ow]=1
    t=SB_tic['time']
    ta=SB_tic['tau']
    if bower_states[ow]==0: #if male returns to a destroyed bower, must repair it
        RB_tau=nexttau(-7)
        SB_tic['tau']=0
        timeline[timeholder]=SB_tic #change the tau on the timeline (not just SB_tic, a copy)
        future_t=RB_tau+t
        if future_t>t_max:
            RB_tau=RB_tau-(future_t-t_max)   
        tic=ticketgenerator(RB_tau,t,ow,-7,ow, t) #immediately, RB_tic starts
        addtotimeline(tic,timeline)
        male_states[ow]=[tic['time']+RB_tau, tic['action'], timeholder] #important!!WONDERING ABOUT THIS -- bc RB->SB
    else:
        MT_FG_time=ta+t
        if MT_FG_time<t_max:
            decider=random.random()
            if decider<MT_vs_FG: #if transition to MT
                targ=numpy.random.choice(list(range(nodes)), p=visit_preferences[ow]) #choosing the male to maurad based on visit preferences
                MT_tau=travel_times[ow][targ]
                future_t=MT_tau+MT_FG_time
                if future_t>t_max:
                    MT_tau=MT_tau-(future_t-t_max)                    
                tic=ticketgenerator(MT_tau,MT_FG_time,ow,-4, targ, t)
                male_states[ow]=[MT_FG_time, tic['action'], timeholder] #important!!
                addtotimeline(tic,timeline)
            else:
                FG_tau=nexttau(-2)
                future_t=FG_tau+MT_FG_time
                if future_t>t_max:
                    FG_tau=FG_tau-(future_t-t_max)   
                tic=ticketgenerator(FG_tau,MT_FG_time,ow,-2, ow, t) #-2 denotes foraging action
                male_states[ow]=[MT_FG_time, tic['action'], timeholder] #important!!
                addtotimeline(tic,timeline)
        else: #if the ticket would be late
            male_states[ow]=[t_max, -10, timeholder] #still need to show male is at bower, but -10 action is gibberish (since male won't leave bower before tmax)
            
            
            
            
#Foraging ticket handler. Ticket read, and male state changes to no longer at bower. Generates a stay at bower ticket.
def FGtickethandler(FG_tic, timeline, t_max, male_states, timeholder):
    ow=FG_tic['owner'] 
    t=FG_tic['time']
    ta=FG_tic['tau']
    #print(male_states[ow])
    if t==0: #in this case male_states[ow]=0
        print("in t==0 (FGth)")
        #male_states[ow]=0 #male is no longer at bower
        SB_time=t+ta
        SB_tau=nexttau(-1)
        if SB_time<t_max:
            future_t=SB_tau+SB_time
            if future_t>t_max:
                SB_tau=SB_tau-(future_t-t_max)               
            SB_tic=ticketgenerator(SB_tau,SB_time,ow,-1, ow, t) #-1 denotes staying at bower
            addtotimeline(SB_tic,timeline)      
    elif male_states[ow][0]!=t:
        discards.append(FG_tic)
        timeline[timeholder]['action']=abs(FG_tic['action']) #A CHANGE
        #print("what we remove:")
        #print(timeline[timeholder]) #the ticket we're getting rid of
        #print("the subsequent ticket:")
        #print(timeline[timeholder+1]) #the ticket we're getting rid of
        #timeline.pop(timeholder)
        #timeholder-=1
        #print("the subsequent ticket again?? hopefully??:")
        #print(timeline[timeholder+1])
    else:
        male_states[ow]=0 #male is no longer at bower
        SB_time=t+ta
        SB_tau=nexttau(-1)
        if SB_time<t_max:
            future_t=SB_tau+SB_time
            if future_t>t_max:
                SB_tau=SB_tau-(future_t-t_max)               
            SB_tic=ticketgenerator(SB_tau,SB_time,ow,-1, ow, t) #-1 denotes staying at bower
            addtotimeline(SB_tic,timeline)
        
#Maurad travel ticket handler. Male state changes to no longer at bower, and generates a maurad action ticket.
def MTtickethandler(MT_tic,timeline,t_max,male_states, timeholder):
    ow=MT_tic['owner']
    targ=MT_tic['target']
    t=MT_tic['time']
    ta=MT_tic['tau']
    if male_states[ow][0]!=t:
        discards.append(MT_tic)
        timeline[timeholder]['action']=abs(MT_tic['action']) #A CHANGE
        #print("what we remove:")
        #print(timeline[timeholder]) #the ticket we're getting rid of
        #print("the subsequent ticket:")
        #print(timeline[timeholder+1]) #the ticket we're getting rid of
        #timeline.pop(timeholder)
        #timeholder-=1
        #print("the subsequent ticket again?? hopefully??:")
        #print(timeline[timeholder+1])
    else:
        male_states[ow]=0 #male is no longer at his bower
        MA_time=t+ta
        if MA_time<t_max:
            MA_tau=nexttau(-5)
            future_t=MA_tau+MA_time
            if future_t>t_max:
                MA_tau=MA_tau-(future_t-t_max)   
            MA_tic=ticketgenerator(MA_tau,MA_time, ow, -5, targ, t) #generate a maurading action ticket
            addtotimeline(MA_tic, timeline)
            
def MAtickethandler(MA_tic, timeline, t_max, male_states, bower_states, travel_times):
    ow=MA_tic['owner'] 
    targ=MA_tic['target']
    if male_states[targ]==0 and bower_states[targ]==1: #if the bower is intact and its owner is absent
        bower_states[targ]=0
    else: #in all other cases bowerbird immediately leaves
        MA_tic['tau']=0 #COMMENT! Changing tau for this ticket as we read it bc stay is cut short by bower owner's presence
    t=MA_tic['time']
    ta=MA_tic['tau']
    MR_time=t+ta
    if MR_time<t_max: 
        MR_tau=travel_times[ow][targ]
        future_t=MR_tau+MR_time
        if future_t>t_max:
            MR_tau=MR_tau-(future_t-t_max)  
        MR_tic=ticketgenerator(MR_tau,MR_time, ow, -6, targ, t)
        addtotimeline(MR_tic, timeline)

            
def MRtickethandler(MR_tic,timeline,t_max):
    ow=MR_tic['owner']
    targ=MR_tic['target'] #accesing the male the owner chose to maurad based on visit preferences
    t=MR_tic['time']
    ta=MR_tic['tau']
    SB_time=t+ta
    if SB_time<t_max:
        SB_tau=nexttau(-1)
        future_t=SB_tau+SB_time
        if future_t>t_max:
            SB_tau=SB_tau-(future_t-t_max)  
        SB_tic=ticketgenerator(SB_tau,SB_time, ow, -1, ow, t) #generate stay at bower ticket
        addtotimeline(SB_tic, timeline)
            
def RBtickethandler(RB_tic, timeline, t_max):
    ow=RB_tic['owner']
    t=RB_tic['time']
    ta=RB_tic['tau']
    SB_time=t+ta
    if SB_time<t_max:
        SB_tau=nexttau(-1)
        future_t=SB_tau+SB_time
        if future_t>t_max:
            SB_tau=SB_tau-(future_t-t_max)  
        SB_tic=ticketgenerator(SB_tau, SB_time, ow, -1, ow, t)
        addtotimeline(SB_tic, timeline)
        

def FVtickethandler(FV_tic, timeline, FV_param, t_max, male_states, fitness_states, nodes, visit_preferences, travel_times, success_rate, success_times, recents_list, max_visits):
    targ=FV_tic['target']
    ow=FV_tic['owner']
    t=FV_tic['time']
    recents_list=d["rl{0}".format(ow)]
    r=random.random() #generate this to decide whether mating happens if other conditions are met
    if bower_states[targ]==1 and male_states[targ]!=0 and r<success_rate and t>mating_states[targ]: #if the bower is intact and the male is present
        tau_court= 0.25 #numpy.random.normal(loc=.1504, scale=.0102, size=1)[0]
        t_court_end=t+tau_court
        if male_states[targ][0]<t_court_end:
            if male_states[targ][1]==-4: #if a MT ticket, generate a new tau and new_targ (individual to be marauded by targ)
                new_targ=numpy.random.choice(list(range(nodes)), p=visit_preferences[targ]) #choosing the male to maurad based on visit preferences
                new_tau=travel_times[new_targ][targ] #tau is based on travel time
            else: #if a FG ticket, generate a new tau and set new_targ to targ
                new_tau=nexttau(male_states[targ][1]) #generate a new tau based on activity
                new_targ=targ #targ=ow (or in this case new_targ=targ) when it's an FG_tic
            future_t=new_tau+t_court_end #future t is the time when the ticket we are generating's action will end
            if future_t>t_max: #if future_t > t_max, change it so the tau hits t_max exactly
                new_tau=new_tau-(future_t-t_max)  
            tic=ticketgenerator(new_tau, t_court_end, targ, male_states[targ][1], new_targ, t) #make a ticket that has the male leaving only once female visit is over
            addtotimeline(tic, timeline)
            SB_tic=timeline[male_states[targ][2]] #this SB ticket has the wrong tau -- we must modify the timeline
            #print("this is the SB_tic with the wrong tau:")
            #print(timeline[male_states[targ][2]])
            SB_tic['tau']=t_court_end-male_states[targ][0]+SB_tic['tau'] #the new tau is generated by tacking on the extension of SB due to FV
            timeline[male_states[targ][2]]['tau']=SB_tic['tau'] #modify the ticket on the timeline itself
            #print("this is the SB_tic with the right tau??:")
            #print(timeline[male_states[targ][2]])
            male_states[targ][0]=t_court_end #now change male states so that the leave_time is accurate 
        mating_states[targ]=t_court_end
#        recents_list=[]
        timeline[timeholder]['tau']=tau_court
        fitness_states[targ]=fitness_states[targ]+1 #assumption: female always mates if bower is intact and male present
        success_times.append(t_court_end) #this is the time at which the mating finishes (not starts, tho it could be)
#        new_FV_targ=numpy.random.choice(list(range(nodes)))
#        decider=random.random() #decide whether female will mate for a second time
#        if decider<.8: #half the time she'll mate again due to predation (or for the heck of it -- PJ said 4-5 matings)
#            new_FV_time=t+tau_court+nexttau(-3) #time that mating ends, plus time before she arrives to mate again
#            if new_FV_time<t_max:
#                new_FV_tic=ticketgenerator(tau_court,new_FV_time, ow, -3, new_FV_targ)
#                addtotimeline(new_FV_tic, timeline)        
    else: #if female does not successfully mate
        recents_list.append(targ)
        if len(recents_list)==min(max_visits, nodes): #if she's already visited her max # of males and not mated, reset recents and use nexttau
            recents_list=[]
            new_FV_targ=numpy.random.choice(list(range(nodes)))
            new_FV_time=t+nexttau(-3) #she goes to another male after waiting some time (nexttau), courting takes no time
            if new_FV_time<t_max:
                new_FV_tic=ticketgenerator(0,new_FV_time, ow, -3, new_FV_targ, t)
                addtotimeline(new_FV_tic, timeline)
        else: #otherwise find a male not in recents and use travel_times
            new_FV_targ=-1 #just so that the code goes into the while loop the first iteration
            while(new_FV_targ in recents_list or new_FV_targ==-1):
                new_FV_targ=numpy.random.choice(list(range(nodes)), p=visit_preferences[targ]) #choose a male based on preference (a function of distance)
            new_FV_time=t+travel_times[targ][new_FV_targ] #she goes directly to this male
            if new_FV_time<t_max:
                new_FV_tic=ticketgenerator(0,new_FV_time, ow, -3, new_FV_targ, t)
                addtotimeline(new_FV_tic, timeline)
    return recents_list



    
    
    
#FOR LATER
#def MTtickethandler (MT_tic, timeline, )

#distance function
def travel(nodes,d,bird_speed):
    node_dist= numpy.array([[-1.0]*nodes]*nodes) #(dist in m)initialize a nodes-by-nodes matrix (1st nrows, 2nd ncols)
    sqrt_nodes=int(math.sqrt(nodes)) 
    node_graph=numpy.arange(nodes)
    node_mat=node_graph.reshape(sqrt_nodes,sqrt_nodes)
    for i in range(sqrt_nodes):
        for j in range (sqrt_nodes):
            n1=node_mat[i][j]
            for a in range(sqrt_nodes):
                for b in range(sqrt_nodes):
                    n2=node_mat[a][b]
                    if n1<n2:
                        d12=math.hypot((i-a)*d,abs(j-b)*d)
                        node_dist[n1][n2]=d12
                        node_dist[n2][n1]=d12
                    if n1==n2:
                        node_dist[n1][n2]=0
    travel_times=numpy.array([[0.0]*nodes]*nodes)
    for i in range(nodes):
        for j in range(nodes):
            travel_times[i][j]=node_dist[i][j]/bird_speed
    return [node_dist,travel_times, node_mat]





travel_mats=travel(nodes,d,bird_speed)
node_dist=travel_mats[0]
travel_times=travel_mats[1]
print(travel_mats[0].astype(int))
print(travel_mats[1])
print(travel_times)




#solve for lambda 
improb=0.99
improb_distance=800
lamb=-math.log(1-improb)/improb_distance

#will write female preference based on cumulative exponential decay (lambda=.00576)
def female_probs(node_dist, nodes, lamb):
    visit_preferences=numpy.array([[0.]*nodes]*nodes)
    for i in range(nodes):
        for j in range(nodes):
            if i!=j:
                visit_preferences[i][j]=math.exp(-lamb*node_dist[i][j])        
        visit_preferences[i]=visit_preferences[i]/sum(visit_preferences[i])
    return visit_preferences

visit_preferences=female_probs(travel_times, nodes, lamb)
#print(visit_preferences)
#print(visit_preferences[1])
print(nodes)
print(visit_preferences)
# Out:
# [[  0 150 150 212]
#  [150   0 212 150]
#  [150 212   0 150]
#  [212 150 150   0]]
# [[0.         0.00347222 0.00347222 0.00491046]
#  [0.00347222 0.         0.00491046 0.00347222]
#  [0.00347222 0.00491046 0.         0.00347222]
#  [0.00491046 0.00347222 0.00347222 0.        ]]
# [[0.         0.00347222 0.00347222 0.00491046]
#  [0.00347222 0.         0.00491046 0.00347222]
#  [0.00347222 0.00491046 0.         0.00347222]
#  [0.00491046 0.00347222 0.00347222 0.        ]]
# 4
# [[0.         0.33333425 0.33333425 0.33333149]
#  [0.33333425 0.         0.33333149 0.33333425]
#  [0.33333425 0.33333149 0.         0.33333425]
#  [0.33333149 0.33333425 0.33333425 0.        ]]

# %%
#just a test


d={}

#changed so they start out foraging not SB!
for i in range(nodes):
    init_FG_time=t+nexttau(-2)
    init_FG_tic=ticketgenerator(init_FG_time-t, t, i, -2, i, {})
    addtotimeline(init_FG_tic, timeline)


#the logic with ts and taus is not parallel to all other ticket types, but it seems to work... maybe change later    
for i in range(int(3*nodes)): #
    first_male=random.choice(list(range(nodes))) #The lucky bowerbird that is chosen by the female first
    first_female_time=0 #determine the time when the first female arrives
    first_female_tic=ticketgenerator(0,first_female_time, i, -3, first_male, {}) #first female ticket
    addtotimeline(first_female_tic, timeline)
    d["rl{0}".format(i)]=[]
    
        
        
print(timeline)
# Out:
# [{'tau': 0.4521398532167407, 'time': 0.0, 'owner': 0, 'action': -2, 'target': 0, 'origin': {}}, {'tau': 0.24640389737292973, 'time': 0.0, 'owner': 1, 'action': -2, 'target': 1, 'origin': {}}, {'tau': 0.09959488843761964, 'time': 0.0, 'owner': 2, 'action': -2, 'target': 2, 'origin': {}}, {'tau': 0.052158387996266785, 'time': 0.0, 'owner': 3, 'action': -2, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 0, 'action': -3, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 1, 'action': -3, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 2, 'action': -3, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 3, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 4, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 5, 'action': -3, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 6, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 7, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 8, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 9, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 10, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 11, 'action': -3, 'target': 2, 'origin': {}}]

# %%
#while loop

while t<t_max:
    print("while loop enter time:")
    print(t)
    if timeholder>(len(timeline)-1): #if timeholder exceeds max timeline index
        print('end')
        break
    next_tic=timeline[timeholder] #look at the ticket corresponding to where we are on the timeline
    action=next_tic['action']
    ow=next_tic['owner']
    if action==-1:
        SBtickethandler(next_tic, timeline, t_max, male_states, MT_vs_FG, visit_preferences, travel_times)
    elif action==-2:
        FGtickethandler(next_tic, timeline, t_max, male_states, timeholder)
    elif action==-3:
        d["rl{0}".format(ow)]=FVtickethandler(next_tic, timeline, FV_param, t_max, male_states, fitness_states, nodes, visit_preferences, travel_times, success_rates, success_times, d["rl{0}".format(ow)], max_visits)
        print("{:d}'s recent's list:".format(ow))
        print(d["rl{0}".format(ow)])
    elif action==-4:
        MTtickethandler(next_tic,timeline,t_max,male_states, timeholder)
    elif action==-5:
        MAtickethandler(next_tic, timeline, t_max, male_states, bower_states, travel_times)
    elif action==-6:
        MRtickethandler(next_tic,timeline,t_max)
    else:
        RBtickethandler(next_tic, timeline, t_max) 
    t=next_tic['time'] #new time based on the ticket we just read
    timeholder=timeholder+1 #increment timeholder

print(timeline)
# Out:
# while loop enter time:
# 0.0
# in t==0 (FGth)
# while loop enter time:
# 0.0
# in t==0 (FGth)
# while loop enter time:
# 0.0
# in t==0 (FGth)
# while loop enter time:
# 0.0
# in t==0 (FGth)
# while loop enter time:
# 0.0
# 0's recent's list:
# [1]
# while loop enter time:
# 0
# 1's recent's list:
# [3]
# while loop enter time:
# 0
# 2's recent's list:
# [3]
# while loop enter time:
# 0
# 3's recent's list:
# [0]
# while loop enter time:
# 0
# 4's recent's list:
# [0]
# while loop enter time:
# 0
# 5's recent's list:
# [1]
# while loop enter time:
# 0
# 6's recent's list:
# [2]
# while loop enter time:
# 0
# 7's recent's list:
# [0]
# while loop enter time:
# 0
# 8's recent's list:
# [0]
# while loop enter time:
# 0
# 9's recent's list:
# [2]
# while loop enter time:
# 0
# 10's recent's list:
# [0]
# while loop enter time:
# 0
# 11's recent's list:
# [2]
# while loop enter time:
# 0
# 0's recent's list:
# [1, 3]
# while loop enter time:
# 0.003472222222222222
# 3's recent's list:
# [0, 1]
# while loop enter time:
# 0.003472222222222222
# 4's recent's list:
# [0, 2]
# while loop enter time:
# 0.003472222222222222
# 5's recent's list:
# [1, 0]
# while loop enter time:
# 0.003472222222222222
# 8's recent's list:
# [0, 2]
# while loop enter time:
# 0.003472222222222222
# 9's recent's list:
# [2, 3]
# while loop enter time:
# 0.003472222222222222
# 10's recent's list:
# [0, 1]
# while loop enter time:
# 0.003472222222222222
# 1's recent's list:
# [3, 0]
# while loop enter time:
# 0.004910463758239914
# 2's recent's list:
# [3, 0]
# while loop enter time:
# 0.004910463758239914
# 6's recent's list:
# [2, 1]
# while loop enter time:
# 0.004910463758239914
# 7's recent's list:
# [0, 3]
# while loop enter time:
# 0.004910463758239914
# 11's recent's list:
# [2, 1]
# while loop enter time:
# 0.004910463758239914
# 3's recent's list:
# [0, 1, 3]
# while loop enter time:
# 0.006944444444444444
# 8's recent's list:
# [0, 2, 3]
# while loop enter time:
# 0.006944444444444444
# 10's recent's list:
# [0, 1, 3]
# while loop enter time:
# 0.006944444444444444
# 0's recent's list:
# [1, 3, 0]
# while loop enter time:
# 0.008382685980462136
# 4's recent's list:
# [0, 2, 1]
# while loop enter time:
# 0.008382685980462136
# 5's recent's list:
# [1, 0, 3]
# while loop enter time:
# 0.008382685980462136
# 9's recent's list:
# [2, 3, 0]
# while loop enter time:
# 0.008382685980462136
# 1's recent's list:
# [3, 0, 2]
# while loop enter time:
# 0.008382685980462136
# 2's recent's list:
# [3, 0, 2]
# while loop enter time:
# 0.008382685980462136
# 6's recent's list:
# [2, 1, 3]
# while loop enter time:
# 0.008382685980462136
# 7's recent's list:
# [0, 3, 2]
# while loop enter time:
# 0.008382685980462136
# 11's recent's list:
# [2, 1, 3]
# while loop enter time:
# 0.008382685980462136
# 3's recent's list:
# []
# while loop enter time:
# 0.010416666666666666
# 8's recent's list:
# []
# while loop enter time:
# 0.010416666666666666
# 10's recent's list:
# []
# while loop enter time:
# 0.010416666666666666
# 0's recent's list:
# []
# while loop enter time:
# 0.011854908202684358
# 4's recent's list:
# []
# while loop enter time:
# 0.011854908202684358
# 5's recent's list:
# []
# while loop enter time:
# 0.011854908202684358
# 9's recent's list:
# []
# while loop enter time:
# 0.011854908202684358
# 1's recent's list:
# []
# while loop enter time:
# 0.01329314973870205
# 2's recent's list:
# []
# while loop enter time:
# 0.01329314973870205
# 6's recent's list:
# []
# while loop enter time:
# 0.01329314973870205
# 7's recent's list:
# []
# while loop enter time:
# 0.01329314973870205
# 11's recent's list:
# []
# while loop enter time:
# 0.01329314973870205
# while loop enter time:
# 0.052158387996266785
# while loop enter time:
# 0.09959488843761964
# while loop enter time:
# 0.12649835157374703
# while loop enter time:
# 0.15829482454987676
# while loop enter time:
# 0.21512819003302952
# while loop enter time:
# 0.21860041225525173
# while loop enter time:
# 0.24640389737292973
# while loop enter time:
# 0.24640389737292973
# while loop enter time:
# 0.274776304528742
# while loop enter time:
# 0.3186004122552517
# while loop enter time:
# 0.3220726344774739
# while loop enter time:
# 0.3751616532246706
# while loop enter time:
# 0.44104556752828306
# while loop enter time:
# 0.4462196478326782
# while loop enter time:
# 0.4521398532167407
# while loop enter time:
# 0.4756162191011453
# while loop enter time:
# 0.4932236573755825
# while loop enter time:
# 0.5537251763932539
# while loop enter time:
# 0.6177563513018965
# while loop enter time:
# 0.6501414815516384
# while loop enter time:
# 0.666078502727522
# while loop enter time:
# 0.6743161708254152
# while loop enter time:
# 0.741015301919197
# while loop enter time:
# 0.8502053353047185
# while loop enter time:
# 0.8813899739925978
# while loop enter time:
# 0.8940635062112323
# while loop enter time:
# 0.9290830280413341
# while loop enter time:
# 1.0157470227509688
# while loop enter time:
# 1.0690080045035972
# while loop enter time:
# 1.1110892840793547
# while loop enter time:
# 1.2081023859886995
# while loop enter time:
# 1.2271618576066259
# while loop enter time:
# 1.239367197766426
# 8's recent's list:
# []
# while loop enter time:
# 1.2559151278673373
# while loop enter time:
# 1.293758972282665
# while loop enter time:
# 1.3061212281249415
# while loop enter time:
# 1.3077168982243295
# while loop enter time:
# 1.308726563776678
# while loop enter time:
# 1.3797499979923389
# while loop enter time:
# 1.4570032398601211
# while loop enter time:
# 1.4583957011624236
# while loop enter time:
# 1.4919351158225846
# while loop enter time:
# 1.5059151278673373
# 6's recent's list:
# [1]
# while loop enter time:
# 1.5417874327949244
# 6's recent's list:
# [1, 3]
# while loop enter time:
# 1.5452596550171467
# while loop enter time:
# 1.54743006304594
# 6's recent's list:
# [1, 3]
# while loop enter time:
# 1.5501701187753867
# while loop enter time:
# 1.603520652823141
# while loop enter time:
# 1.655513087013159
# while loop enter time:
# 1.7496858003235778
# while loop enter time:
# 1.795196773285356
# while loop enter time:
# 1.7986689955075783
# while loop enter time:
# 1.8001701187753867
# 0's recent's list:
# [3]
# while loop enter time:
# 1.8589670662540951
# 0's recent's list:
# [3, 1]
# while loop enter time:
# 1.8624392884763175
# 0's recent's list:
# [3, 1, 0]
# while loop enter time:
# 1.8659115106985398
# 11's recent's list:
# [1]
# while loop enter time:
# 1.868629768138974
# 0's recent's list:
# []
# while loop enter time:
# 1.869383732920762
# 11's recent's list:
# [1, 0]
# while loop enter time:
# 1.8721019903611964
# 11's recent's list:
# [1, 0, 2]
# while loop enter time:
# 1.8755742125834187
# 11's recent's list:
# []
# while loop enter time:
# 1.879046434805641
# while loop enter time:
# 1.8986689955075784
# while loop enter time:
# 1.9021412177298007
# while loop enter time:
# 1.9654295472114511
# while loop enter time:
# 1.9654295472114511
# while loop enter time:
# 2.013625833704535
# while loop enter time:
# 2.2176333051651294
# while loop enter time:
# 2.2356887340172378
# while loop enter time:
# 2.2464038973729297
# while loop enter time:
# 2.3462807380957504
# while loop enter time:
# 2.350151334773203
# while loop enter time:
# 2.4258612383289924
# while loop enter time:
# 2.473363252558849
# while loop enter time:
# 2.473791471833614
# while loop enter time:
# 2.5134816815833987
# while loop enter time:
# 2.5661426065955757
# while loop enter time:
# 2.6001224090374375
# while loop enter time:
# 2.6171909336865595
# while loop enter time:
# 2.688950135067824
# while loop enter time:
# 2.761875747054379
# while loop enter time:
# 2.8006179254168035
# 2's recent's list:
# [2]
# while loop enter time:
# 2.8257347859033435
# 2's recent's list:
# [2, 1]
# while loop enter time:
# 2.8306452496615835
# 2's recent's list:
# [2, 1]
# while loop enter time:
# 2.834117471883806
# while loop enter time:
# 2.8488472692583797
# while loop enter time:
# 2.9859973887909335
# while loop enter time:
# 3.0262479014773156
# while loop enter time:
# 3.084117471883806
# while loop enter time:
# 3.087589694106028
# while loop enter time:
# 3.087589694106028
# while loop enter time:
# 3.090945538056347
# while loop enter time:
# 3.0910619163282504
# 11's recent's list:
# []
# while loop enter time:
# 3.153919964049921
# while loop enter time:
# 3.2350681560243837
# while loop enter time:
# 3.2859562574901955
# while loop enter time:
# 3.3434464580343546
# while loop enter time:
# 3.3466785007219912
# while loop enter time:
# 3.403919964049921
# while loop enter time:
# 3.4531371422970603
# while loop enter time:
# 3.507131133242991
# while loop enter time:
# 3.5167967982296027
# while loop enter time:
# 3.531159204500323
# while loop enter time:
# 3.6297558021550254
# while loop enter time:
# 3.638729230715212
# while loop enter time:
# 3.731221334810579
# while loop enter time:
# 3.8784281861701246
# while loop enter time:
# 3.887315192721976
# while loop enter time:
# 3.9585274584241588
# while loop enter time:
# 3.965429547211451
# while loop enter time:
# 3.967334914492061
# while loop enter time:
# 3.970807136714283
# while loop enter time:
# 3.970807136714283
# while loop enter time:
# 3.9742793589365055
# 7's recent's list:
# []
# while loop enter time:
# 3.9932548542387156
# while loop enter time:
# 4.006221477634651
# while loop enter time:
# 4.037200880195931
# while loop enter time:
# 4.04211134395417
# while loop enter time:
# 4.04211134395417
# while loop enter time:
# 4.04702180771241
# while loop enter time:
# 4.048534614992664
# while loop enter time:
# 4.170914486019646
# while loop enter time:
# 4.191547153235324
# while loop enter time:
# 4.243254854238716
# while loop enter time:
# 4.2966712671313605
# while loop enter time:
# 4.43246962899556
# while loop enter time:
# 4.437091745593248
# 9's recent's list:
# [3]
# while loop enter time:
# 4.44180342075288
# 9's recent's list:
# [3, 1]
# while loop enter time:
# 4.445275642975102
# 9's recent's list:
# [3, 1]
# while loop enter time:
# 4.450186106733342
# while loop enter time:
# 4.465636315416378
# while loop enter time:
# 4.498996077920754
# while loop enter time:
# 4.5368833631514605
# 4's recent's list:
# []
# while loop enter time:
# 4.562854839175586
# while loop enter time:
# 4.5744850931262535
# while loop enter time:
# 4.619590766656823
# while loop enter time:
# 4.659178017813893
# 1's recent's list:
# [3]
# while loop enter time:
# 4.659337339315314
# 1's recent's list:
# [3]
# while loop enter time:
# 4.662809561537537
# while loop enter time:
# 4.700186106733342
# while loop enter time:
# 4.716108885897006
# 5's recent's list:
# [3]
# while loop enter time:
# 4.755822685865013
# 5's recent's list:
# [3, 0]
# while loop enter time:
# 4.760733149623253
# 5's recent's list:
# [3, 0, 2]
# while loop enter time:
# 4.764205371845475
# 5's recent's list:
# []
# while loop enter time:
# 4.769115835603714
# while loop enter time:
# 4.814838627994226
# while loop enter time:
# 4.826665139540433
# while loop enter time:
# 4.8332038892714655
# while loop enter time:
# 4.8615060426349235
# while loop enter time:
# 4.912809561537537
# while loop enter time:
# 4.960750101765264
# while loop enter time:
# 4.967123126731773
# while loop enter time:
# 4.974327081643506
# while loop enter time:
# 5.072348404456895
# while loop enter time:
# 5.082180093423375
# while loop enter time:
# 5.124821571306421
# while loop enter time:
# 5.132787500827435
# while loop enter time:
# 5.151122280713442
# 10's recent's list:
# [0]
# while loop enter time:
# 5.17253628450107
# 10's recent's list:
# [0]
# while loop enter time:
# 5.177446748259309
# while loop enter time:
# 5.224603919732258
# while loop enter time:
# 5.225456528453792
# while loop enter time:
# 5.310714072283049
# while loop enter time:
# 5.323833004729881
# while loop enter time:
# 5.378669688418013
# while loop enter time:
# 5.379616601956947
# while loop enter time:
# 5.4168122896033015
# while loop enter time:
# 5.427446748259309
# while loop enter time:
# 5.4310698047601225
# while loop enter time:
# 5.459326800968136
# while loop enter time:
# 5.518150489849852
# while loop enter time:
# 5.545901305693639
# while loop enter time:
# 5.595783574162255
# while loop enter time:
# 5.599255796384477
# while loop enter time:
# 5.6058382798808495
# while loop enter time:
# 5.639228395821
# while loop enter time:
# 5.6570806780978495
# while loop enter time:
# 5.6570806780978495
# while loop enter time:
# 5.66779502530513
# while loop enter time:
# 5.6992557963844765
# while loop enter time:
# 5.702728018606699
# while loop enter time:
# 5.751382226486338
# while loop enter time:
# 5.784523684521944
# while loop enter time:
# 5.810531013305797
# while loop enter time:
# 5.905783121076384
# while loop enter time:
# 5.90914913068591
# while loop enter time:
# 5.909907056478123
# 3's recent's list:
# [3]
# while loop enter time:
# 5.930675677433885
# 3's recent's list:
# [3, 2]
# while loop enter time:
# 5.934147899656107
# 3's recent's list:
# [3, 2]
# while loop enter time:
# 5.9376201218783295
# while loop enter time:
# 5.9555843873302985
# while loop enter time:
# 5.961407722146609
# while loop enter time:
# 6.095340309202741
# while loop enter time:
# 6.1876201218783295
# while loop enter time:
# 6.203476413001914
# while loop enter time:
# 6.209168724238002
# while loop enter time:
# 6.232351009546755
# while loop enter time:
# 6.295065059218531
# while loop enter time:
# 6.401186888200678
# while loop enter time:
# 6.403530883755362
# while loop enter time:
# 6.41064002207076
# while loop enter time:
# 6.433705997339246
# while loop enter time:
# 6.474497721580223
# while loop enter time:
# 6.49276988077669
# while loop enter time:
# 6.554013225816256
# while loop enter time:
# 6.6323381603585805
# while loop enter time:
# 6.668284489490891
# while loop enter time:
# 6.714828968364737
# while loop enter time:
# 6.754154169946336
# while loop enter time:
# 6.768592028252641
# while loop enter time:
# 6.772064250474863
# while loop enter time:
# 6.772064250474863
# while loop enter time:
# 6.775536472697086
# while loop enter time:
# 6.850244763498387
# while loop enter time:
# 6.89226191627096
# while loop enter time:
# 6.900214127955889
# while loop enter time:
# 7.051198699037614
# while loop enter time:
# 7.067596724112059
# while loop enter time:
# 7.0809750760794
# while loop enter time:
# 7.143555840344267
# while loop enter time:
# 7.193631338880508
# while loop enter time:
# 7.2275585345748015
# while loop enter time:
# 7.240506282397091
# while loop enter time:
# 7.292379849453383
# while loop enter time:
# 7.357076546997355
# while loop enter time:
# 7.385847458857275
# while loop enter time:
# 7.423778722967179
# 0's recent's list:
# [3]
# while loop enter time:
# 7.431192637116108
# 0's recent's list:
# [3, 1]
# while loop enter time:
# 7.43466485933833
# 0's recent's list:
# [3, 1]
# while loop enter time:
# 7.438137081560552
# while loop enter time:
# 7.5645420092194655
# while loop enter time:
# 7.646783805641797
# while loop enter time:
# 7.6570806780978495
# while loop enter time:
# 7.684401231144177
# while loop enter time:
# 7.706862060170813
# while loop enter time:
# 7.709712466372643
# while loop enter time:
# 7.801486020384101
# while loop enter time:
# 7.808720812667026
# while loop enter time:
# 7.8121930348892485
# while loop enter time:
# 7.8261826419848095
# while loop enter time:
# 7.831544870212404
# while loop enter time:
# 7.831544870212404
# while loop enter time:
# 7.912193034889248
# while loop enter time:
# 7.9156652571114705
# while loop enter time:
# 7.930095832471407
# while loop enter time:
# 8.049078443858779
# while loop enter time:
# 8.13120767570513
# while loop enter time:
# 8.178483216565061
# while loop enter time:
# 8.245282562108253
# while loop enter time:
# 8.248700408470958
# while loop enter time:
# 8.264445416792583
# while loop enter time:
# 8.304042309089617
# while loop enter time:
# 8.334302399491522
# while loop enter time:
# 8.352366451613019
# while loop enter time:
# 8.353128909343683
# while loop enter time:
# 8.451670271990206
# while loop enter time:
# 8.485176737076937
# while loop enter time:
# 8.58266309012478
# while loop enter time:
# 8.617503691433464
# while loop enter time:
# 8.635512626717924
# while loop enter time:
# 8.672360958765392
# while loop enter time:
# 8.713323598772533
# while loop enter time:
# 8.751934024817565
# while loop enter time:
# 8.792543164975669
# while loop enter time:
# 8.836428755685857
# 5's recent's list:
# []
# while loop enter time:
# 8.971155993822492
# while loop enter time:
# 9.016332482628552
# while loop enter time:
# 9.06181116015435
# while loop enter time:
# 9.067506080423662
# while loop enter time:
# 9.08452184779028
# while loop enter time:
# 9.181037683221517
# while loop enter time:
# 9.221155993822492
# while loop enter time:
# 9.308940489897026
# while loop enter time:
# 9.332837489634661
# while loop enter time:
# 9.338704579886668
# while loop enter time:
# 9.407127586392457
# while loop enter time:
# 9.418050375373907
# while loop enter time:
# 9.532416063979921
# while loop enter time:
# 9.5467364772026
# while loop enter time:
# 9.698332524437163
# while loop enter time:
# 9.698371061753113
# while loop enter time:
# 9.708998734578232
# while loop enter time:
# 9.780743197332455
# while loop enter time:
# 9.792008515946234
# while loop enter time:
# 9.831544870212404
# while loop enter time:
# 9.846224529720164
# while loop enter time:
# 9.93995626666153
# while loop enter time:
# 9.944468736054882
# while loop enter time:
# 10.068453351345733
# while loop enter time:
# 10.074164955122919
# while loop enter time:
# 10.086069785682174
# while loop enter time:
# 10.18858369502898
# while loop enter time:
# 10.191630834049976
# while loop enter time:
# 10.245031660734897
# while loop enter time:
# 10.263684639222516
# while loop enter time:
# 10.34840447555398
# while loop enter time:
# 10.371229204702367
# while loop enter time:
# 10.373020588527304
# while loop enter time:
# 10.387317770196066
# while loop enter time:
# 10.42165804318167
# while loop enter time:
# 10.464798878794149
# while loop enter time:
# 10.49982447075486
# while loop enter time:
# 10.514628801032412
# while loop enter time:
# 10.532761267215248
# while loop enter time:
# 10.533043990513063
# while loop enter time:
# 10.558095704520953
# while loop enter time:
# 10.560222376544848
# while loop enter time:
# 10.57076187749547
# while loop enter time:
# 10.641724875835092
# while loop enter time:
# 10.658262395625082
# while loop enter time:
# 10.687187265680624
# while loop enter time:
# 10.710709141530588
# while loop enter time:
# 10.771017336925572
# while loop enter time:
# 10.855092582646934
# while loop enter time:
# 10.86730763263643
# while loop enter time:
# 10.923379818818617
# while loop enter time:
# 10.959961810495367
# while loop enter time:
# 10.978721933859878
# while loop enter time:
# 10.98050100710863
# while loop enter time:
# 11.04353615730525
# while loop enter time:
# 11.063204401365796
# while loop enter time:
# 11.114225185912268
# while loop enter time:
# 11.174307343126742
# while loop enter time:
# 11.194000396045483
# while loop enter time:
# 11.218282645724578
# while loop enter time:
# 11.288891682868233
# while loop enter time:
# 11.302816184677
# while loop enter time:
# 11.330488499982621
# while loop enter time:
# 11.404556947931752
# while loop enter time:
# 11.459684724855165
# while loop enter time:
# 11.462259497354932
# while loop enter time:
# 11.482757253501468
# while loop enter time:
# 11.495940036525232
# while loop enter time:
# 11.50088059275258
# while loop enter time:
# 11.638482164155935
# while loop enter time:
# 11.641533448256215
# while loop enter time:
# 11.720926635910896
# while loop enter time:
# 11.723794497924619
# while loop enter time:
# 11.725186621123857
# while loop enter time:
# 11.779823900135767
# while loop enter time:
# 11.815862456912475
# while loop enter time:
# 11.855601374223113
# while loop enter time:
# 11.879725867167249
# while loop enter time:
# 11.921883288375255
# while loop enter time:
# 11.956858666653641
# while loop enter time:
# 11.962603471438168
# end
# [{'tau': 0.4521398532167407, 'time': 0.0, 'owner': 0, 'action': -2, 'target': 0, 'origin': {}}, {'tau': 0.24640389737292973, 'time': 0.0, 'owner': 1, 'action': -2, 'target': 1, 'origin': {}}, {'tau': 0.09959488843761964, 'time': 0.0, 'owner': 2, 'action': -2, 'target': 2, 'origin': {}}, {'tau': 0.052158387996266785, 'time': 0.0, 'owner': 3, 'action': -2, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 0, 'action': -3, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 1, 'action': -3, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 2, 'action': -3, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 3, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 4, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 5, 'action': -3, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 6, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 7, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 8, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 9, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 10, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 11, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 0, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 3, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 4, 'action': -3, 'target': 2, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 5, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 8, 'action': -3, 'target': 2, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 9, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 10, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 1, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 2, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 6, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 7, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 11, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 3, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 8, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 10, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 0, 'action': -3, 'target': 0, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 4, 'action': -3, 'target': 1, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 5, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 9, 'action': -3, 'target': 0, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 1, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 2, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 6, 'action': -3, 'target': 3, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 7, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 11, 'action': -3, 'target': 3, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.010416666666666666, 'owner': 3, 'action': -3, 'target': 2, 'origin': 0.006944444444444444}, {'tau': 0, 'time': 0.010416666666666666, 'owner': 8, 'action': -3, 'target': 1, 'origin': 0.00694444 ...

# %%
print(timeline)
# Out:
# [{'tau': 0.4521398532167407, 'time': 0.0, 'owner': 0, 'action': -2, 'target': 0, 'origin': {}}, {'tau': 0.24640389737292973, 'time': 0.0, 'owner': 1, 'action': -2, 'target': 1, 'origin': {}}, {'tau': 0.09959488843761964, 'time': 0.0, 'owner': 2, 'action': -2, 'target': 2, 'origin': {}}, {'tau': 0.052158387996266785, 'time': 0.0, 'owner': 3, 'action': -2, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 0, 'action': -3, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 1, 'action': -3, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 2, 'action': -3, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 3, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 4, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 5, 'action': -3, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 6, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 7, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 8, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 9, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 10, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 11, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 0, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 3, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 4, 'action': -3, 'target': 2, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 5, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 8, 'action': -3, 'target': 2, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 9, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 10, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 1, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 2, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 6, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 7, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 11, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 3, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 8, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 10, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 0, 'action': -3, 'target': 0, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 4, 'action': -3, 'target': 1, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 5, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 9, 'action': -3, 'target': 0, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 1, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 2, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 6, 'action': -3, 'target': 3, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 7, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 11, 'action': -3, 'target': 3, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.010416666666666666, 'owner': 3, 'action': -3, 'target': 2, 'origin': 0.006944444444444444}, {'tau': 0, 'time': 0.010416666666666666, 'owner': 8, 'action': -3, 'target': 1, 'origin': 0.00694444 ...

# %%
fitness_states
success_times
# Out:
# [1.5059151278673373,
#  1.8001701187753867,
#  3.084117471883806,
#  3.403919964049921,
#  4.243254854238716,
#  4.700186106733342,
#  4.812854839175586,
#  4.912809561537537,
#  5.427446748259309,
#  6.1876201218783295,
#  7.688137081560552,
#  9.221155993822492]

# %%
d={}

for i in range(nodes):
    d["tl{0}".format(i)]=[]
for j in range(len(timeline[0:timeholder])):
    #for i in range(nodes):
     #   if timeline[j]['owner']==i:
    if timeline[j]['action']==-3:
        d["tl{0}".format(timeline[j]['target'])].append(timeline[j])  
    else:
        d["tl{0}".format(timeline[j]['owner'])].append(timeline[j])

print("tl0----")
print(d["tl0"])
print("tl1----")
print(d["tl1"])
print("tl2----")
print(d["tl2"])
print("tl3----")
print(d["tl3"])


for i in range(nodes):
    tl=d["tl{0}".format(i)]
    l=len(tl)
    ta=[0]
    fem=[]
    for j in range(l):
        if tl[j]['action']!=-3: #female visit taus don't mean anything for the male bc she isn't necessarily coming back to the same male
            ta.append(tl[j]['time'])
        else:
            fem.append(tl[j]['time'])
    d["times{0}".format(i)]=ta
    d["fvtimes{0}".format(i)]=fem

#print("times0----")
#print(d["times0"])
#print("times1----")
#print(d["times1"])
#print("times2----")
#print(d["times2"])
#print("times3----")
#print(d["times3"]) 

#append tmax - sumoftaus to each list (so it reaches tmax exactly)
for i in range(nodes):
    d["times{0}".format(i)].append(t_max)


import csv
timess=[d["times0"],d["times1"],d["times2"],d["times3"]]
csvfile = "example_times2"
with open(csvfile, "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    writer.writerows(timess)
femtimess=[]
for i in range(nodes):
    femtimess.append(d["fvtimes{0}".format(i)])

csvfile = "example_fvtimes"
with open(csvfile, "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    writer.writerows(femtimess)
# Out:
# tl0----
# [{'tau': 0.4521398532167407, 'time': 0.0, 'owner': 0, 'action': -2, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 3, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 4, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 7, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 8, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 10, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 5, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 1, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 2, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 0, 'action': -3, 'target': 0, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 9, 'action': -3, 'target': 0, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.01329314973870205, 'owner': 6, 'action': -3, 'target': 0, 'origin': 0.008382685980462136}, {'tau': 0, 'time': 0.01329314973870205, 'owner': 11, 'action': -3, 'target': 0, 'origin': 0.008382685980462136}, {'tau': 0.10158532317651323, 'time': 0.4521398532167407, 'owner': 0, 'action': -1, 'target': 0, 'origin': 0.0}, {'tau': 0.06403117490864264, 'time': 0.5537251763932539, 'owner': 0, 'action': -2, 'target': 0, 'origin': 0.4521398532167407}, {'tau': 0.04832215142562547, 'time': 0.6177563513018965, 'owner': 0, 'action': -1, 'target': 0, 'origin': 0.5537251763932539}, {'tau': 0.2153114712650758, 'time': 0.666078502727522, 'owner': 0, 'action': -2, 'target': 0, 'origin': 0.6177563513018965}, {'tau': 0.18761803051099946, 'time': 0.8813899739925978, 'owner': 0, 'action': -1, 'target': 0, 'origin': 0.666078502727522}, {'tau': 0.04208127957575753, 'time': 1.0690080045035972, 'owner': 0, 'action': -2, 'target': 0, 'origin': 0.8813899739925978}, {'tau': 0.09701310190934487, 'time': 1.1110892840793547, 'owner': 0, 'action': -1, 'target': 0, 'origin': 1.0690080045035972}, {'tau': 0.09801884213624196, 'time': 1.2081023859886995, 'owner': 0, 'action': -2, 'target': 0, 'origin': 1.1110892840793547}, {'tau': 0.15227447303748218, 'time': 1.3061212281249415, 'owner': 0, 'action': -1, 'target': 0, 'origin': 1.2081023859886995}, {'tau': 0.033539414660161124, 'time': 1.4583957011624236, 'owner': 0, 'action': -2, 'target': 0, 'origin': 1.3061212281249415}, {'tau': 0.30823500295280204, 'time': 1.4919351158225846, 'owner': 0, 'action': -1, 'target': 0, 'origin': 1.4583957011624236}, {'tau': 0.25, 'time': 1.5501701187753867, 'owner': 6, 'action': -3, 'target': 0, 'origin': 1.5452596550171467}, {'tau': 0.42724225971401225, 'time': 1.655513087013159, 'owner': 0, 'action': 2, 'target': 0, 'origin': 1.4919351158225846}, {'tau': 0.43551861524185115, 'time': 1.8001701187753867, 'owner': 0, 'action': -2, 'target': 0, 'origin': 1.5501701187753867}, {'tau': 0, 'time': 1.8659115106985398, 'owner': 0, 'action': -3, 'target': 0, 'origin': 1.8624392884763175}, {'tau': 0, 'time': 1.8721019903611964, 'owner': 11, 'action': -3, 'target': 0, 'origin': 1.868629768138974}, {'tau': 0.11059200407851273, 'time': 2.2356887340172378, 'owner': 0, 'action': -1, 'target': 0, 'origin': 1.8001701187753867}, {'tau': 0.07958050023324197, 'time': 2.3462807380957504, 'owner': 0, 'action': -2, 'target': 0, 'origin': 2.2356887340172378}, {'tau': 0.0479302335046215, 'time': 2.4258612383289924, 'owner': 0, 'action': -1, 'target': 0, 'origin': 2.3462807380957504}, {'tau': 0.09235113476196204, 'time': 2.473791471833614, 'owner': 0, 'action': -2, 'target': 0, 'origin': 2.4258612383289924}, {'tau': 0.19573314045880327, 'time': 2.5661426065955757, 'owner': 0, 'action': -1, 'target': 0, 'origin': 2.473791471833614}, {'tau': 0.22412164173655438, 'time': 2.761875747054379, 'owner': 0, 'action': -2, 'target': 0, 'origin': 2.5661426065955757}, {'tau': 0.10494814926541346, 'time': 2.9859973887909335, 'owner': 0, ' ...
# tl1----
# [{'tau': 0.24640389737292973, 'time': 0.0, 'owner': 1, 'action': -2, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 0, 'action': -3, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 5, 'action': -3, 'target': 1, 'origin': {}}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 3, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 10, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 6, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 11, 'action': -3, 'target': 1, 'origin': 0}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 4, 'action': -3, 'target': 1, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.010416666666666666, 'owner': 8, 'action': -3, 'target': 1, 'origin': 0.006944444444444444}, {'tau': 0, 'time': 0.011854908202684358, 'owner': 9, 'action': -3, 'target': 1, 'origin': 0.008382685980462136}, {'tau': 0, 'time': 0.01329314973870205, 'owner': 1, 'action': -3, 'target': 1, 'origin': 0.008382685980462136}, {'tau': 0, 'time': 0.01329314973870205, 'owner': 2, 'action': -3, 'target': 1, 'origin': 0.008382685980462136}, {'tau': 0, 'time': 0.01329314973870205, 'owner': 7, 'action': -3, 'target': 1, 'origin': 0.008382685980462136}, {'tau': 0, 'time': 0.24640389737292973, 'owner': 1, 'action': -1, 'target': 1, 'origin': 0.0}, {'tau': 2, 'time': 0.24640389737292973, 'owner': 1, 'action': -7, 'target': 1, 'origin': 0.24640389737292973}, {'tau': 0, 'time': 1.5417874327949244, 'owner': 6, 'action': -3, 'target': 1, 'origin': 0.01329314973870205}, {'tau': 0, 'time': 1.8624392884763175, 'owner': 0, 'action': -3, 'target': 1, 'origin': 1.8589670662540951}, {'tau': 0, 'time': 1.868629768138974, 'owner': 11, 'action': -3, 'target': 1, 'origin': 0.01329314973870205}, {'tau': 0.2670777842104692, 'time': 2.2464038973729297, 'owner': 1, 'action': -1, 'target': 1, 'origin': 0.24640389737292973}, {'tau': 0.08664072745403889, 'time': 2.5134816815833987, 'owner': 1, 'action': -2, 'target': 1, 'origin': 2.2464038973729297}, {'tau': 0.08882772603038665, 'time': 2.6001224090374375, 'owner': 1, 'action': -1, 'target': 1, 'origin': 2.5134816815833987}, {'tau': 0.3372977664094913, 'time': 2.688950135067824, 'owner': 1, 'action': -2, 'target': 1, 'origin': 2.6001224090374375}, {'tau': 0, 'time': 2.8306452496615835, 'owner': 2, 'action': -3, 'target': 1, 'origin': 2.8257347859033435}, {'tau': 0.2088202545470682, 'time': 3.0262479014773156, 'owner': 1, 'action': -1, 'target': 1, 'origin': 2.688950135067824}, {'tau': 0.10837830200997095, 'time': 3.2350681560243837, 'owner': 1, 'action': -2, 'target': 1, 'origin': 3.0262479014773156}, {'tau': 0.29528277268085756, 'time': 3.3434464580343546, 'owner': 1, 'action': -1, 'target': 1, 'origin': 3.2350681560243837}, {'tau': 0.24858596200676378, 'time': 3.638729230715212, 'owner': 1, 'action': -2, 'target': 1, 'origin': 3.3434464580343546}, {'tau': 0.1498856874739549, 'time': 3.887315192721976, 'owner': 1, 'action': -1, 'target': 1, 'origin': 3.638729230715212}, {'tau': 0.004910463758239914, 'time': 4.037200880195931, 'owner': 1, 'action': -4, 'target': 2, 'origin': 3.887315192721976}, {'tau': 0, 'time': 4.04211134395417, 'owner': 1, 'action': -5, 'target': 2, 'origin': 4.037200880195931}, {'tau': 0.004910463758239914, 'time': 4.04211134395417, 'owner': 1, 'action': -6, 'target': 2, 'origin': 4.04211134395417}, {'tau': 0.14452534552291446, 'time': 4.04702180771241, 'owner': 1, 'action': -1, 'target': 1, 'origin': 4.04211134395417}, {'tau': 0.3829379398909294, 'time': 4.191547153235324, 'owner': 1, 'action': -2, 'target': 1, 'origin': 4.04702180771241}, {'tau': 0, 'time': 4.445275642975102, 'owner': 9, 'action': -3, 'target': 1, 'origin': 4.44180342075288}, {'tau': 0.33832446841128333, 'time': 4.5744850931262535, 'owner': 1, 'action': -1, 'target': 1, 'origin': 4.191547153235324}, {'tau': 0.25, 'time': 4.662809561537537, 'owner': 1, 'action': -3, 'target': 1, 'orig ...
# tl2----
# [{'tau': 0.09959488843761964, 'time': 0.0, 'owner': 2, 'action': -2, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 6, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 9, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 11, 'action': -3, 'target': 2, 'origin': {}}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 4, 'action': -3, 'target': 2, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 8, 'action': -3, 'target': 2, 'origin': 0}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 1, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 2, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 7, 'action': -3, 'target': 2, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.010416666666666666, 'owner': 3, 'action': -3, 'target': 2, 'origin': 0.006944444444444444}, {'tau': 0, 'time': 0.010416666666666666, 'owner': 10, 'action': -3, 'target': 2, 'origin': 0.006944444444444444}, {'tau': 0, 'time': 0.011854908202684358, 'owner': 0, 'action': -3, 'target': 2, 'origin': 0.008382685980462136}, {'tau': 0, 'time': 0.011854908202684358, 'owner': 5, 'action': -3, 'target': 2, 'origin': 0.008382685980462136}, {'tau': 0.17518141609112237, 'time': 0.09959488843761964, 'owner': 2, 'action': -1, 'target': 2, 'origin': 0.0}, {'tau': 0.10038534869592856, 'time': 0.274776304528742, 'owner': 2, 'action': -2, 'target': 2, 'origin': 0.09959488843761964}, {'tau': 0.07105799460800762, 'time': 0.3751616532246706, 'owner': 2, 'action': -1, 'target': 2, 'origin': 0.274776304528742}, {'tau': 0.029396571268467123, 'time': 0.4462196478326782, 'owner': 2, 'action': -2, 'target': 2, 'origin': 0.3751616532246706}, {'tau': 0.17452526245049313, 'time': 0.4756162191011453, 'owner': 2, 'action': -1, 'target': 2, 'origin': 0.4462196478326782}, {'tau': 0.0241746892737767, 'time': 0.6501414815516384, 'owner': 2, 'action': -2, 'target': 2, 'origin': 0.4756162191011453}, {'tau': 0.1758891644793033, 'time': 0.6743161708254152, 'owner': 2, 'action': -1, 'target': 2, 'origin': 0.6501414815516384}, {'tau': 0.16554168744625034, 'time': 0.8502053353047185, 'owner': 2, 'action': -2, 'target': 2, 'origin': 0.6743161708254152}, {'tau': 0.211414834855657, 'time': 1.0157470227509688, 'owner': 2, 'action': -1, 'target': 2, 'origin': 0.8502053353047185}, {'tau': 0.06659711467603924, 'time': 1.2271618576066259, 'owner': 2, 'action': -2, 'target': 2, 'origin': 1.0157470227509688}, {'tau': 0.014967591494012972, 'time': 1.293758972282665, 'owner': 2, 'action': -1, 'target': 2, 'origin': 1.2271618576066259}, {'tau': 0.07102343421566092, 'time': 1.308726563776678, 'owner': 2, 'action': -2, 'target': 2, 'origin': 1.293758972282665}, {'tau': 0.07725324186778228, 'time': 1.3797499979923389, 'owner': 2, 'action': -1, 'target': 2, 'origin': 1.308726563776678}, {'tau': 0.09042682318581899, 'time': 1.4570032398601211, 'owner': 2, 'action': -2, 'target': 2, 'origin': 1.3797499979923389}, {'tau': 0.2022557372776376, 'time': 1.54743006304594, 'owner': 2, 'action': -1, 'target': 2, 'origin': 1.4570032398601211}, {'tau': 0.21574374688787343, 'time': 1.7496858003235778, 'owner': 2, 'action': -2, 'target': 2, 'origin': 1.54743006304594}, {'tau': 0, 'time': 1.869383732920762, 'owner': 0, 'action': -3, 'target': 2, 'origin': 1.8659115106985398}, {'tau': 0, 'time': 1.8755742125834187, 'owner': 11, 'action': -3, 'target': 2, 'origin': 1.8721019903611964}, {'tau': 0, 'time': 1.9654295472114511, 'owner': 2, 'action': -1, 'target': 2, 'origin': 1.7496858003235778}, {'tau': 2, 'time': 1.9654295472114511, 'owner': 2, 'action': -7, 'target': 2, 'origin': 1.9654295472114511}, {'tau': 0, 'time': 2.8257347859033435, 'owner': 2, 'action': -3, 'target': 2, 'origin': 0.01329314973870205}, {'tau': 0.27782530702726427, 'time': 3.965429547211451, 'owner': 2, 'action': -1, 'target': 2, 'origin': 1.9654295472114511}, {'tau': 0.25, 't ...
# tl3----
# [{'tau': 0.052158387996266785, 'time': 0.0, 'owner': 3, 'action': -2, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 1, 'action': -3, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 2, 'action': -3, 'target': 3, 'origin': {}}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 0, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.003472222222222222, 'owner': 9, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.004910463758239914, 'owner': 7, 'action': -3, 'target': 3, 'origin': 0}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 3, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 8, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.006944444444444444, 'owner': 10, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 5, 'action': -3, 'target': 3, 'origin': 0.003472222222222222}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 6, 'action': -3, 'target': 3, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.008382685980462136, 'owner': 11, 'action': -3, 'target': 3, 'origin': 0.004910463758239914}, {'tau': 0, 'time': 0.011854908202684358, 'owner': 4, 'action': -3, 'target': 3, 'origin': 0.008382685980462136}, {'tau': 0.07433996357748024, 'time': 0.052158387996266785, 'owner': 3, 'action': -1, 'target': 3, 'origin': 0.0}, {'tau': 0.03179647297612974, 'time': 0.12649835157374703, 'owner': 3, 'action': -2, 'target': 3, 'origin': 0.052158387996266785}, {'tau': 0.056833365483152765, 'time': 0.15829482454987676, 'owner': 3, 'action': -1, 'target': 3, 'origin': 0.12649835157374703}, {'tau': 0.003472222222222222, 'time': 0.21512819003302952, 'owner': 3, 'action': -4, 'target': 1, 'origin': 0.15829482454987676}, {'tau': 0.1, 'time': 0.21860041225525173, 'owner': 3, 'action': -5, 'target': 1, 'origin': 0.21512819003302952}, {'tau': 0.003472222222222222, 'time': 0.3186004122552517, 'owner': 3, 'action': -6, 'target': 1, 'origin': 0.21860041225525173}, {'tau': 0.11897293305080915, 'time': 0.3220726344774739, 'owner': 3, 'action': -1, 'target': 3, 'origin': 0.3186004122552517}, {'tau': 0.05217808984729942, 'time': 0.44104556752828306, 'owner': 3, 'action': -2, 'target': 3, 'origin': 0.3220726344774739}, {'tau': 0.2477916445436144, 'time': 0.4932236573755825, 'owner': 3, 'action': -1, 'target': 3, 'origin': 0.44104556752828306}, {'tau': 0.15304820429203533, 'time': 0.741015301919197, 'owner': 3, 'action': -2, 'target': 3, 'origin': 0.4932236573755825}, {'tau': 0.035019521830101805, 'time': 0.8940635062112323, 'owner': 3, 'action': -1, 'target': 3, 'origin': 0.741015301919197}, {'tau': 0.3102841697250919, 'time': 0.9290830280413341, 'owner': 3, 'action': -2, 'target': 3, 'origin': 0.8940635062112323}, {'tau': 0.26654793010091127, 'time': 1.239367197766426, 'owner': 3, 'action': -1, 'target': 3, 'origin': 0.9290830280413341}, {'tau': 0.25, 'time': 1.2559151278673373, 'owner': 8, 'action': -3, 'target': 3, 'origin': 0.010416666666666666}, {'tau': 0.04137935096628578, 'time': 1.3077168982243295, 'owner': 3, 'action': 2, 'target': 3, 'origin': 1.239367197766426}, {'tau': 0.09760552495580375, 'time': 1.5059151278673373, 'owner': 3, 'action': -2, 'target': 3, 'origin': 1.2559151278673373}, {'tau': 0, 'time': 1.5452596550171467, 'owner': 6, 'action': -3, 'target': 3, 'origin': 1.5417874327949244}, {'tau': 0.19167612046221505, 'time': 1.603520652823141, 'owner': 3, 'action': -1, 'target': 3, 'origin': 1.5059151278673373}, {'tau': 0.003472222222222222, 'time': 1.795196773285356, 'owner': 3, 'action': -4, 'target': 2, 'origin': 1.603520652823141}, {'tau': 0.1, 'time': 1.7986689955075783, 'owner': 3, 'action': -5, 'target': 2, 'origin': 1.795196773285356}, {'tau': 0, 'time': 1.8589670662540951, 'owner': 0, 'action': -3, 'target': 3, 'origin': 0.011854908202684358}, {'tau': 0, 'time': 1.879046434805641, 'owner': 11, 'action': -3, 'target': 3, 'origin': 1.8755 ...

# %%
#PERCENTS NEED TO ADD UP

#Percentage times at bower not currently correct-- based on all guard!!!!
#Will recalculate in the future after changing mating to not be instantaneous 
for i in range(nodes):
    tl=d["tl{0}".format(i)]
    l=len(tl)
    ta=[]
    accSB=0
    accFG=0
    accM=0
    accRB=0
    allacc=0
    FV_list=[]
    for j in range(l):
        if tl[j]['action']!=-3: #female visit taus don't mean anything for the male bc she isn't necessarily coming back to the same male
            ta.append(tl[j]['tau'])
            #print("time according to taus is {:f}".format(allacc))
            #print("time according to tickets is {:f}".format(tl[j]['time']))
            allacc+=tl[j]['tau']
            if tl[j]['action']==-1:
                accSB=accSB+tl[j]['tau']
                #print("action: {:d}, tau: {:f}".format(tl[j]['action'], tl[j]['tau']))
            elif tl[j]['action']==-2:
                accFG=accFG+tl[j]['tau']
                #print("action: {:d}, tau: {:f}".format(tl[j]['action'], tl[j]['tau']))
            elif tl[j]['action']==-7:
                accRB=accRB+tl[j]['tau']
                #print("action: {:d}, tau: {:f}".format(tl[j]['action'], tl[j]['tau']))
            elif tl[j]['action']==-4 or tl[j]['action']==-5 or tl[j]['action']==-6:
                accM=accM+tl[j]['tau']  
                #print("action: {:d}, tau: {:f}".format(tl[j]['action'], tl[j]['tau']))
        else:
            #print("FV")
            FV_list.append(tl[j])
    d["taus{0}".format(i)]=ta
    su=sum([accSB/t_max, accM/t_max, accFG/t_max, accRB/t_max])
    if su==1:
        print("WE GOOD!: {:f}".format(su))
    else:
        print("NOT GOOD!: {:f}".format(su))
    print("Bird {:d}'s % time at bower is {:f}".format(i, accSB/t_max)) 
    print("Bird {:d}'s % time marauding is {:f}".format(i, accM/t_max)) 
    print("Bird {:d}'s % time foraging is {:f}".format(i, accFG/t_max)) 
    print("Bird {:d}'s % time repairing bower is {:f}".format(i, accRB/t_max)) 
    print("Bird {:d}'s separate accs sum to {:f}".format(i,(accSB+accM+accFG+accRB)))
    print("Bird {:d}'s allacc is {:f}".format(i,allacc))
    
#append tmax - sumoftaus to each list (so it reaches tmax exactly) --IS THIS EVEN OK?
#for i in range(nodes):
#    d["taus{0}".format(i)].append(t_max-sum(d["taus{0}".format(i)]))
    
    
print("taus0 sum----")
#print(d["taus0"])
print(sum(d["taus0"]))
print("taus1 sum----")
#print(d["taus1"])
print(sum(d["taus1"]))
print("taus2 sum----")
#print(d["taus2"])
print(sum(d["taus2"]))
print("taus3 sum----")
#print(d["taus3"]) 
print(sum(d["taus3"]))
# Out:
# NOT GOOD!: 1.000000
# Bird 0's % time at bower is 0.509037
# Bird 0's % time marauding is 0.010069
# Bird 0's % time foraging is 0.480893
# Bird 0's % time repairing bower is 0.000000
# Bird 0's separate accs sum to 12.000000
# Bird 0's allacc is 12.511245
# WE GOOD!: 1.000000
# Bird 1's % time at bower is 0.359907
# Bird 1's % time marauding is 0.000818
# Bird 1's % time foraging is 0.305942
# Bird 1's % time repairing bower is 0.333333
# Bird 1's separate accs sum to 12.000000
# Bird 1's allacc is 12.521400
# NOT GOOD!: 1.000000
# Bird 2's % time at bower is 0.380611
# Bird 2's % time marauding is 0.000000
# Bird 2's % time foraging is 0.286056
# Bird 2's % time repairing bower is 0.333333
# Bird 2's separate accs sum to 12.000000
# Bird 2's allacc is 12.141016
# NOT GOOD!: 1.000000
# Bird 3's % time at bower is 0.578692
# Bird 3's % time marauding is 0.027315
# Bird 3's % time foraging is 0.393993
# Bird 3's % time repairing bower is 0.000000
# Bird 3's separate accs sum to 12.000000
# Bird 3's allacc is 12.701185
# taus0 sum----
# 12.511245006718605
# taus1 sum----
# 12.521399663382438
# taus2 sum----
# 12.141015776689649
# taus3 sum----
# 12.701185421289003

# %%
print(success_times)
print(len(success_times))
# Out:
# [1.5059151278673373, 1.8001701187753867, 3.084117471883806, 3.403919964049921, 4.243254854238716, 4.700186106733342, 4.812854839175586, 4.912809561537537, 5.427446748259309, 6.1876201218783295, 7.688137081560552, 9.221155993822492]
# 12

# %%
plt.hist(success_times)
plt.show()

# %%
print(len(femtimess))
#print(femtimess)
fts = [item for sublist in femtimess for item in sublist]
print(len(fts))
# Out:
# 4
# 84

# %%
print(len(discards))
print(discards)
# Out:
# 10
# [{'tau': 0.04137935096628578, 'time': 1.3077168982243295, 'owner': 3, 'action': 2, 'target': 3, 'origin': 1.239367197766426}, {'tau': 0.42724225971401225, 'time': 1.655513087013159, 'owner': 0, 'action': 2, 'target': 0, 'origin': 1.4919351158225846}, {'tau': 0.003472222222222222, 'time': 2.8488472692583797, 'owner': 3, 'action': 4, 'target': 1, 'origin': 2.8006179254168035}, {'tau': 0.47633533377517456, 'time': 3.2859562574901955, 'owner': 3, 'action': 2, 'target': 3, 'origin': 3.0910619163282504}, {'tau': 0.07859528768596974, 'time': 4.006221477634651, 'owner': 2, 'action': 2, 'target': 2, 'origin': 3.965429547211451}, {'tau': 0.06242048900368002, 'time': 4.5368833631514605, 'owner': 2, 'action': 2, 'target': 2, 'origin': 4.2966712671313605}, {'tau': 0.1566041094978494, 'time': 4.716108885897006, 'owner': 1, 'action': 2, 'target': 1, 'origin': 4.5744850931262535}, {'tau': 0.1799985143253215, 'time': 5.224603919732258, 'owner': 3, 'action': 2, 'target': 3, 'origin': 4.967123126731773}, {'tau': 0.08400274700459408, 'time': 5.961407722146609, 'owner': 0, 'action': 2, 'target': 0, 'origin': 5.905783121076384}, {'tau': 0.36479555388458773, 'time': 9.08452184779028, 'owner': 1, 'action': 2, 'target': 1, 'origin': 8.751934024817565}]

# %%
fitness_states
# Out:
# [3, 2, 2, 5]
