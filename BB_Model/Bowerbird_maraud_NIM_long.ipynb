# %%
#Key
#Notes- Paramters contain underscores, while functions don't
#SB: Stay at bower
#FG: Foraging
#MT: Maraud travel (travel to rival's bower)
#MA: Maraud action (destroy bower if absent, have antagonistic interaction in present)
#MR: Maraud return (return to own bower)
#RB: Repair own bower
#MT_vs_FG: the probability of next transition away from SB being to MT (otherwise it would be to FG)
#a=-1: denotes a staying at bower action on ticket
#a=-2: denotes a foraging action on ticket
#a=-3: denotes a female visiting action on a ticket
#a=-4: denotes travel to another male's bower
#a=-5: denotes marauding of another male's bower
#a=-6: denotes returning from another male's bower
#a=-7: denotes a bower repair action on a ticket
#target: the male/node an action is preformed on. For maurading, the target is the bird under potential attack. For mating, target is male being mated with. For other activities other then maurading and mating, owner and target are the same.
#owner: The male or female actively performing an action. For mating, the female is the owner. For all other activities, the owner is male.
#networkwriter: generates network where everybird is connected
#addtotimeline: adds tickets to timeline
#travel_times_linear_p: generates a matrix that contains the probabilities of travelling to a given a bower 
#if the relationship between distance and travel preference is linear
#improb: The probability of traveling improb_distance or less
#improb_distance: The distance at which there is only a (1-improb)% chance of choosing to travel
#lamb: lambda calculated by solving improb=1-numpy.exp(-lamb*improb_distance)
#bower_states: options are 1 (bower intact) and 0 (bower destroyed-will never be the case when all guarders) and another value for time that mating will end (assuming mating is happening)
#male_states: options are [leave_time, leave_action, SB_timeholder] (male present at bower) and 0 (male absent from bower)
#fitness_states: keeps track of number of matings a given male has had
#t: time
#nodes: total number of male bowerbirds in the network
#node_dist: the node by nde matrix with distances between each node
#node_graph: matrix with individuals 1 through nodes numbered by going through each row
#tau: Length of time an activity takes. If a foraging ticket has a tau of 0.5 and occurs at t=1, then the bird is foraging for 30 minutes, at which point a SB activity will start (at t=1.5).
#t_court: the amount of time it takes a female to court+mate with a male, generated from a normal distribution


import math
import random
import numpy as numpy
import matplotlib.pyplot as plt


#Parameters:
t=0.0 #start at time 0
t_max=12#12*4*30 #2 months in hrs (assume no nights so 12 hr = 1 day)
timeholder=0
timeline=[] #initialize the timeline
discards=[] #where we put the old version of tickets that get over-written/moved
#We've moved away from using these params with expovariate (how we handle FV is still TBD)
#So THE BELOW 3 SHOULD BE COMMENTED OUT (but rn we don't want the handler funcs to yell at us)
FV_param=[1, t_max/2] #5days, tmax/3 #0.2 #nodes/0.19 #totally random
FG_param=3 #larger values lead to foraging ending earlier, because taus are smaller
SB_param=1.5 #larger values lead to bowerstay ending earlier, because taus are smaller
RB_param=2 #made up -- takes 30mins (every time -- no distribution) to repair bower
MA_param=.1 #made up -- takes 6mins (every time -- no distribution) to maraud bower
MT_vs_FG=.05 #compared 20 feedings/day to .1 maraudings/hr
nodes=100
bower_states=[1]*nodes
male_states=[0]*nodes #start at foraging now
mating_states=[0]*nodes
fitness_states=[0]*nodes
success_rate=1
success_times=[] #going to change this to be a vector of times when the female leaves (at this point, sucessful mating has occured)
recents_list=[]
max_visits=6 #STEEEEVEEEE
bird_speed=12*3600 #m/hr (12m/s)
d=500.0
FperM=3 #number of sexually mature females per sexually mature males in a bowerbird population
num_sims=100

def ticketgenerator(tau,t, o, a, targ, t2):
    ticket={
        'tau': tau, #how long the activity lasts
        'time': t, #time at which the activity starts
        'owner': o, #who is doing the activity (could be a female if action=-3)
        'action': a, #which activity (see key)
        'target': targ, #target of the activity (owner=target unless action=-3,-4,-5, or -6)
        'origin': t2 #the time of the ticket that generated this one
    }
    return ticket;

#adds new tickets to timeline -- Stefano, any more efficient suggestions for keeping timeline in order?
def addtotimeline(tic): #A CHANGE
    if not timeline:
        timeline.append(tic)
    else:
        ind=len(timeline)-1
        end=0
        while (tic['time']<timeline[ind]['time'] and end==0): #moves backwards until it finds where to place the ticket based on the listed times
            ind=ind-1 
            if(ind<0):
                end=1
        ind=ind+1
        timeline.insert(ind, tic)


#travel time
#distance function
def travel(nodes,d,bird_speed):
    node_dist= numpy.array([[-1.0]*nodes]*nodes) #(dist in m)initialize a nodes-by-nodes matrix (1st nrows, 2nd ncols)
    sqrt_nodes=int(math.sqrt(nodes)) 
    node_graph=numpy.arange(nodes)
    node_mat=node_graph.reshape(sqrt_nodes,sqrt_nodes)
    for i in range(sqrt_nodes):
        for j in range (sqrt_nodes):
            n1=node_mat[i][j]
            for a in range(sqrt_nodes):
                for b in range(sqrt_nodes):
                    n2=node_mat[a][b]
                    if n1<n2:
                        d12=math.hypot((i-a)*d,abs(j-b)*d)
                        node_dist[n1][n2]=d12
                        node_dist[n2][n1]=d12
                    if n1==n2:
                        node_dist[n1][n2]=0
    travel_times=numpy.array([[0.0]*nodes]*nodes)
    for i in range(nodes):
        for j in range(nodes):
            travel_times[i][j]=node_dist[i][j]/bird_speed
    return [node_dist,travel_times, node_mat]




travel_mats=travel(nodes,d,bird_speed)
travel_times=travel_mats[1]



# function for determining the next time based on our rate parameters
def nexttau(action, ow, targ, new_t):
    new_tau=-1
    while new_tau<=0:
        switcher = { #NOTE: used abs
            -1: numpy.random.normal(loc=.1583, scale=.09755, size=1)[0], #choose when to leave bower (generate a tau for bower stay)
            -2: numpy.random.gamma(shape=1.5, scale=5, size=1)[0]/60, #choose when to stop foraging (generate a tau for foraging)
            -3: numpy.random.uniform(FV_param[0], FV_param[1]), #FV_param... totally arbitrary so we should think about it
            -4: travel_times[ow][targ],
            -5: MA_param, #in the future we'll do something with it
            -6: travel_times[targ][ow],
            -7: RB_param #in the future we'll do something with it 
        }
        new_tau=switcher.get(action)
    future_t=new_tau+new_t #time on future ticket will be the current time plus the tau
    if future_t>t_max: 
        new_tau=(new_tau-(future_t-t_max)) #this ensures that the tau+t won't exceed t_max
    return new_tau

def futurebuilder(old_tic, new_ac, new_targ):
    old_t=old_tic['time']
    new_t=old_t+old_tic['tau']
    new_tic={}
    if new_t<t_max:
        ow=old_tic['owner']
        new_tic=ticketgenerator(nexttau(new_ac, ow, new_targ, new_t), new_t, ow, new_ac, new_targ, old_t)
        addtotimeline(new_tic)
    return new_tic
    
    
#solve for lambda 
improb=0.99
improb_distance=800
lamb=-math.log(1-improb)/improb_distance

#will write female preference based on cumulative exponential decay (lambda=.00576)
def femaleprobs(node_dist, nodes, lamb):
    visit_preferences=numpy.array([[0.]*nodes]*nodes)
    for i in range(nodes):
        for j in range(nodes):
            if i!=j:
                visit_preferences[i][j]=math.exp(-lamb*node_dist[i][j])        
        visit_preferences[i]=visit_preferences[i]/sum(visit_preferences[i])
    return visit_preferences

visit_preferences=femaleprobs(travel_times, nodes, lamb)


#Stay at bower ticket handler. Ticket is read, and male state changes to at bower. 
#The tickethandler can generate then generate a repair bower, foraging, or maurad travel ticket.
def SBtickethandler(SB_tic):
    ow=SB_tic['owner'] #the owner of the ticket is the male bird from the stay at bower ticket
    if male_states[ow]!=0: #because any male who is at his bower was last repairing his bower (not coming from foraging or maurading) 
        bower_states[ow]=1 #now the bower is intact, so the bower state is updated to reflect this change
    if bower_states[ow]==0: #if male returns to a destroyed bower, must repair it
        new_tic=futurebuilder(SB_tic, -7, ow) #generate a new tau and ticket with repair bower action, and add it to the timeline
    else: #if the bower is intact
        decider=random.random()
        if decider<MT_vs_FG: #transition to MT
            targ=numpy.random.choice(list(range(nodes)), p=visit_preferences[ow]) #choosing the male to maurad based on visit preferences
            new_tic=futurebuilder(SB_tic, -4, targ) #generate a new tau and ticket with maurad travel action, and add it to the timeline
        else:
            new_tic=futurebuilder(SB_tic, -2, ow) #generate a new tau and ticket with foraging action, and add it to the timeline
    if new_tic=={}: 
        male_states[ow]=[t_max, -10, timeholder] #still need to show male is at bower, but -10 action is gibberish (since male won't leave bower before tmax)
    else: 
        if new_tic['action']==-7: #If the next action will be repair bower
            male_states[ow]=1 #A CHANGE: we don't know when male will leave bower but we need to state he is at bower now
        else:
            male_states[ow]=[new_tic['time'],new_tic['action'],timeholder]
            
            
            
#Foraging ticket handler. Ticket read, and male state changes to no longer at bower. Generates a stay at bower ticket.
def FGtickethandler(FG_tic):
    ow=FG_tic['owner'] 
    t=FG_tic['time']
    ta=FG_tic['tau']
    #print(male_states[ow])
    if t==0: #in this case male_states[ow]=0
        #male_states[ow]=0 #male is no longer at bower (this for if males start at SB)
        futurebuilder(FG_tic,-1,ow)   
    elif male_states[ow][0]!=t:
        discards.append(FG_tic)
        timeline[timeholder]['action']=abs(FG_tic['action']) 
    else:
        male_states[ow]=0 #male is no longer at bower
        futurebuilder(FG_tic, -1, ow)
        
#Maurad travel ticket handler. Male state changes to no longer at bower, and generates a maurad action ticket.
def MTtickethandler(MT_tic):
    ow=MT_tic['owner']
    targ=MT_tic['target']
    t=MT_tic['time']
    if male_states[ow][0]!=t:
        discards.append(MT_tic)
        timeline[timeholder]['action']=abs(MT_tic['action']) #A CHANGE
        #print("malestates is {:f} while tictime is {:f}".format(male_states[ow][0], t))
    else:
        male_states[ow]=0 #male is no longer at his bower
        futurebuilder(MT_tic, -5, targ)

#Maurad action ticket handler. The bower destruction occurs if the targeted bower's owner is absent and the bower is intact. 
#Otherwise, the tau for this ticket is zero (bird immediately turns around). This ticket handler then generates a
#maurad return ticket.
def MAtickethandler(MA_tic):
    targ=MA_tic['target']
    if male_states[targ]==0 and bower_states[targ]==1: #if the bower is intact and its owner is absent
        bower_states[targ]=0
    else: #in all other cases bowerbird immediately leaves
        MA_tic['tau']=0 #COMMENT! Changing tau for this ticket as we read it bc stay is cut short by bower owner's presence
    futurebuilder(MA_tic, -6, targ)


#Repair bower / maurad return ticket handler. This ticket handler then generates a ticket for stay at bower.
def RBMRtickethandler(RBMR_tic):
    ow=RBMR_tic['owner']
    futurebuilder(RBMR_tic, -1, ow)

       
    
#Female visitation ticket handler. Females visit and mate with males if the following conditions are met: 
#(1) The male is at the bower, (2) the bower is intact, and (3) no other female is present.
#If not,the female keeps this male on her recents list, and travels to additional males with probabilities based on a preference matrix,
#If the female finds no eligeble males but her recents list is full, a longer tau is generated. 
#Her short term memory is cleared (the recents list), and she can try any of the males again. This continues 
#until she mates succusfully. Then, the male tickets for stay at bower are extended until the female leaves. 
def FVtickethandler(FV_tic, recents_list):
    targ=FV_tic['target']
    ow=FV_tic['owner']
    t=FV_tic['time']
    recents_list=d["rl{0}".format(ow)]
    r=random.random() #generate this to decide whether mating happens if other conditions are met
    if bower_states[targ]==1 and male_states[targ]!=0 and r<success_rate and t>mating_states[targ]: #if the bower is intact and the male is present
        tau_court= 0.25 #numpy.random.normal(loc=.1504, scale=.0102, size=1)[0]
        timeline[timeholder]['tau']=tau_court #if mating is successful, then it takes .25hrs
        t_court_end=t+tau_court
        mating_states[targ]=t_court_end
        fitness_states[targ]=fitness_states[targ]+1 #assumption: female always mates if bower is intact and male present
        success_times.append(t_court_end) #this is the time at which the mating finishes (not starts, tho it could be)       
        if male_states[targ][0]<t_court_end:
            SB_tic=timeline[male_states[targ][2]] #this SB ticket has the wrong tau -- we must modify the timeline
            SB_tic['tau']=t_court_end-male_states[targ][0]+SB_tic['tau'] #the new tau is generated by tacking on the extension of SB due to FV
            timeline[male_states[targ][2]]['tau']=SB_tic['tau'] #modify the ticket on the timeline itself
            if male_states[targ][1]==-4: #if a MT ticket, generate a new tau and new_targ (individual to be marauded by targ)
                new_targ=numpy.random.choice(list(range(nodes)), p=visit_preferences[targ]) #choosing the male to maurad based on visit preferences
            else: #if a FG ticket, generate a new tau and set new_targ to targ
                new_targ=targ #targ=ow (or in this case new_targ=targ) when it's an FG_tic
            futurebuilder(SB_tic, male_states[targ][1], new_targ)
            male_states[targ][0]=t_court_end #now change male states so that the leave_time is accurate 
    else: #if female does not successfully mate
        #HEY!!: tau is court time not time until next FV... consider changing to use futurebuilder
        recents_list.append(targ)
        if len(recents_list)==min(max_visits, nodes): #if she's already visited her max # of males and not mated, reset recents and use nexttau
            recents_list=[]
            new_FV_targ=numpy.random.choice(list(range(nodes)), p=visit_preferences[targ])
            new_FV_time=t+numpy.random.uniform(FV_param[0], FV_param[1]) #she goes to another male after waiting some time (nexttau), courting takes no time
            if new_FV_time<t_max:
                new_FV_tic=ticketgenerator(0,new_FV_time, ow, -3, new_FV_targ, t)
                addtotimeline(new_FV_tic)
        else: #otherwise find a male not in recents and use travel_times
            new_FV_targ=-1 #just so that the code goes into the while loop the first iteration
            while(new_FV_targ in recents_list or new_FV_targ==-1):
                new_FV_targ=numpy.random.choice(list(range(nodes)), p=visit_preferences[targ]) #choose a male based on preference (a function of distance)
            new_FV_time=t+travel_times[targ][new_FV_targ] #she goes directly to this male
            if new_FV_time<t_max:
                new_FV_tic=ticketgenerator(0,new_FV_time, ow, -3, new_FV_targ, t)
                addtotimeline(new_FV_tic)
    return recents_list

# %%
#Seed the timeline

sims_fitness_states=[[0.0]*nodes]*nodes
for j in range(num_sims):
    t=0.0 #start at time 0

    timeholder=0
    timeline=[] #initialize the timeline
    discards=[] #where we put the old version of tickets that get over-written/moved
    bower_states=[1]*nodes
    male_states=[0]*nodes #start at foraging now
    mating_states=[0]*nodes
    fitness_states=[0]*nodes
    recents_list=[]

    d={}

    #changed so they start out foraging not SB!
    for i in range(nodes):
        init_FG_time=t+nexttau(-2, i, i, 0)
        init_FG_tic=ticketgenerator(init_FG_time-t, t, i, -2, i, {})
        addtotimeline(init_FG_tic)

    #the logic with ts and taus is not parallel to all other ticket types, but it seems to work... maybe change later    
    for i in range(int(FperM*nodes)): #
        first_male=random.choice(list(range(nodes))) #The lucky bowerbird that is chosen by the female first
        first_female_time=0 #determine the time when the first female arrives
        first_female_tic=ticketgenerator(0,first_female_time, i, -3, first_male, {}) #first female ticket
        addtotimeline(first_female_tic)
        d["rl{0}".format(i)]=[]

    #read tickets, generate more tickets, and move through the timeline until t_max is reached

    while t<t_max:
        if timeholder>(len(timeline)-1): #if timeholder exceeds max timeline index
            print('end')
            break
        next_tic=timeline[timeholder] #look at the ticket corresponding to where we are on the timeline
        action=next_tic['action']
        ow=next_tic['owner']
        if action==-1:
            SBtickethandler(next_tic)
        elif action==-2:
            FGtickethandler(next_tic)
        elif action==-3:
            d["rl{0}".format(ow)]=FVtickethandler(next_tic, d["rl{0}".format(ow)])
        elif action==-4:
            MTtickethandler(next_tic)
        elif action==-5:
            MAtickethandler(next_tic)
        else:
            RBMRtickethandler(next_tic) 
        t=next_tic['time'] #new time based on the ticket we just read
        timeholder=timeholder+1 #increment timeholder
    sims_fitness_states[j]=fitness_states
# Out:
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end

# %%
print(male_states[ow])
# Out:
# [12, -10, 9019]

# %%
#print(timeline)

# %%
d={}

for i in range(nodes):
    d["tl{0}".format(i)]=[]
for j in range(len(timeline[0:timeholder])):
    #for i in range(nodes):
     #   if timeline[j]['owner']==i:
    if timeline[j]['action']==-3:
        d["tl{0}".format(timeline[j]['target'])].append(timeline[j])  
    else:
        d["tl{0}".format(timeline[j]['owner'])].append(timeline[j])

print("tl0----")
print(d["tl0"])
#print("tl1----")
#print(d["tl1"])
#print("tl2----")
#print(d["tl2"])
#print("tl3----")
#print(d["tl3"])
# Out:
# tl0----
# [{'tau': 0.12386036970996611, 'time': 0.0, 'owner': 0, 'action': -2, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 4, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 15, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 103, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 193, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 214, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 216, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0, 'owner': 233, 'action': -3, 'target': 0, 'origin': {}}, {'tau': 0, 'time': 0.07411023422954686, 'owner': 134, 'action': -3, 'target': 0, 'origin': 0}, {'tau': 0, 'time': 0.11818405730240716, 'owner': 191, 'action': -3, 'target': 0, 'origin': 0.08346183508018494}, {'tau': 0.2611837162132114, 'time': 0.12386036970996611, 'owner': 0, 'action': -1, 'target': 0, 'origin': 0.0}, {'tau': 0.25, 'time': 0.13504408592317754, 'owner': 256, 'action': -3, 'target': 0, 'origin': 0.04173091754009247}, {'tau': 0, 'time': 0.15595129686687875, 'owner': 151, 'action': -3, 'target': 0, 'origin': 0.08184106263733189}, {'tau': 0, 'time': 0.19148152483006403, 'owner': 23, 'action': -3, 'target': 0, 'origin': 0.09888893223747143}, {'tau': 0.03873951371047345, 'time': 0.2447414093732065, 'owner': 0, 'action': 2, 'target': 0, 'origin': 0.12386036970996611}, {'tau': 0, 'time': 0.27745328040988154, 'owner': 31, 'action': -3, 'target': 0, 'origin': 0.2195829100395112}, {'tau': 0, 'time': 0.28999668197134687, 'owner': 212, 'action': -3, 'target': 0, 'origin': 0.15062637434643608}, {'tau': 0, 'time': 0.31415798528024436, 'owner': 153, 'action': -3, 'target': 0, 'origin': 0.22376157699428773}, {'tau': 0, 'time': 0.34888543124453547, 'owner': 252, 'action': -3, 'target': 0, 'origin': 0.23969583480869516}, {'tau': 0, 'time': 0.38315346824559704, 'owner': 184, 'action': -3, 'target': 0, 'origin': 0.24378316062068622}, {'tau': 0.15347833456946564, 'time': 0.3850440859231775, 'owner': 0, 'action': -2, 'target': 0, 'origin': 0.12386036970996611}, {'tau': 0, 'time': 0.459466846428624, 'owner': 174, 'action': -3, 'target': 0, 'origin': 0.36687425383603145}, {'tau': 0, 'time': 0.48506920690691707, 'owner': 126, 'action': -3, 'target': 0, 'origin': 0.3752678992621817}, {'tau': 0.09484166362409188, 'time': 0.5385224204926431, 'owner': 0, 'action': -1, 'target': 0, 'origin': 0.3850440859231775}, {'tau': 0.306216102456305, 'time': 0.633364084116735, 'owner': 0, 'action': -2, 'target': 0, 'origin': 0.5385224204926431}, {'tau': 0.2782153168554173, 'time': 0.93958018657304, 'owner': 0, 'action': -1, 'target': 0, 'origin': 0.633364084116735}, {'tau': 0.18464474241529114, 'time': 1.2177955034284573, 'owner': 0, 'action': -2, 'target': 0, 'origin': 0.93958018657304}, {'tau': 0.13342316688091962, 'time': 1.4024402458437484, 'owner': 0, 'action': -1, 'target': 0, 'origin': 1.2177955034284573}, {'tau': 0.16436868750784775, 'time': 1.535863412724668, 'owner': 0, 'action': -2, 'target': 0, 'origin': 1.4024402458437484}, {'tau': 0.32661609164308425, 'time': 1.7002321002325158, 'owner': 0, 'action': -1, 'target': 0, 'origin': 1.535863412724668}, {'tau': 0.25, 'time': 1.7768481918755998, 'owner': 126, 'action': -3, 'target': 0, 'origin': 1.7189778215052294}, {'tau': 0.1496040059107397, 'time': 1.8038146482770148, 'owner': 0, 'action': 2, 'target': 0, 'origin': 1.7002321002325158}, {'tau': 0.06448407150769582, 'time': 2.0268481918756, 'owner': 0, 'action': -2, 'target': 0, 'origin': 1.7002321002325158}, {'tau': 0.04716446185152155, 'time': 2.091332263383296, 'owner': 0, 'action': -1, 'target': 0, 'origin': 2.0268481918756}, {'tau': 0.10850757083547187, 'time': 2.1384967252348175, 'owner': 0, 'action': -2, 'target': 0, 'origin': 2.091332263383296}, {'tau': 0.1553679188367958, 'time': 2.247004296070289, 'owner': 0, 'action': -1, 'target': 0, 'origin': 2.1384967252348175}, {'tau': 0.14151818222667714, 'time': 2.4023 ...

# %%
for i in range(nodes):
    tl=d["tl{0}".format(i)]
    l=len(tl)
    ta=[]
    accSB=0
    accFG=0
    accM=0
    accRB=0
    allacc=0
    FV_list=[]
    for j in range(l):
        if tl[j]['action']!=-3: #female visit taus don't mean anything for the male bc she isn't necessarily coming back to the same male
            if tl[j]['action']<0:
                ta.append(tl[j]['tau'])
            #print("time according to taus is {:f}".format(allacc))
            #print("time according to tickets is {:f}".format(tl[j]['time']))
                allacc+=tl[j]['tau']
            if tl[j]['action']==-1:
                accSB=accSB+tl[j]['tau']
                #print("action: {:d}, tau: {:f}".format(tl[j]['action'], tl[j]['tau']))
            elif tl[j]['action']==-2:
                accFG=accFG+tl[j]['tau']
                #print("action: {:d}, tau: {:f}".format(tl[j]['action'], tl[j]['tau']))
            elif tl[j]['action']==-7:
                accRB=accRB+tl[j]['tau']
                #print("action: {:d}, tau: {:f}".format(tl[j]['action'], tl[j]['tau']))
            elif tl[j]['action']==-4 or tl[j]['action']==-5 or tl[j]['action']==-6:
                accM=accM+tl[j]['tau']  
                #print("action: {:d}, tau: {:f}".format(tl[j]['action'], tl[j]['tau']))
        else:
            #print("FV")
            FV_list.append(tl[j])
    d["taus{0}".format(i)]=ta
    su=sum([accSB/t_max, accM/t_max, accFG/t_max, accRB/t_max])
    print("DOES IT ADD UP: {:f}".format(su))
    print("Bird {:d}'s % time at bower is {:f}".format(i, accSB/t_max)) 
    print("Bird {:d}'s % time marauding is {:f}".format(i, accM/t_max)) 
    print("Bird {:d}'s % time foraging is {:f}".format(i, accFG/t_max)) 
    print("Bird {:d}'s % time repairing bower is {:f}".format(i, accRB/t_max)) 
    print("Bird {:d}'s separate accs sum to {:f}".format(i,(accSB+accM+accFG+accRB)))
    print("Bird {:d}'s allacc is {:f}".format(i,allacc))
# Out:
# DOES IT ADD UP: 1.000000
# Bird 0's % time at bower is 0.545549
# Bird 0's % time marauding is 0.051283
# Bird 0's % time foraging is 0.403168
# Bird 0's % time repairing bower is 0.000000
# Bird 0's separate accs sum to 12.000000
# Bird 0's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 1's % time at bower is 0.486270
# Bird 1's % time marauding is 0.036425
# Bird 1's % time foraging is 0.310638
# Bird 1's % time repairing bower is 0.166667
# Bird 1's separate accs sum to 12.000000
# Bird 1's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 2's % time at bower is 0.584799
# Bird 2's % time marauding is 0.015288
# Bird 2's % time foraging is 0.399912
# Bird 2's % time repairing bower is 0.000000
# Bird 2's separate accs sum to 12.000000
# Bird 2's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 3's % time at bower is 0.575832
# Bird 3's % time marauding is 0.011734
# Bird 3's % time foraging is 0.412434
# Bird 3's % time repairing bower is 0.000000
# Bird 3's separate accs sum to 12.000000
# Bird 3's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 4's % time at bower is 0.567517
# Bird 4's % time marauding is 0.012647
# Bird 4's % time foraging is 0.419837
# Bird 4's % time repairing bower is 0.000000
# Bird 4's separate accs sum to 12.000000
# Bird 4's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 5's % time at bower is 0.637202
# Bird 5's % time marauding is 0.027945
# Bird 5's % time foraging is 0.334853
# Bird 5's % time repairing bower is 0.000000
# Bird 5's separate accs sum to 12.000000
# Bird 5's allacc is 12.000000
# DOES IT ADD UP: 0.408327
# Bird 6's % time at bower is 0.274183
# Bird 6's % time marauding is 0.000000
# Bird 6's % time foraging is 0.134143
# Bird 6's % time repairing bower is 0.000000
# Bird 6's separate accs sum to 4.899919
# Bird 6's allacc is 4.899919
# DOES IT ADD UP: 1.000000
# Bird 7's % time at bower is 0.602325
# Bird 7's % time marauding is 0.019687
# Bird 7's % time foraging is 0.377988
# Bird 7's % time repairing bower is 0.000000
# Bird 7's separate accs sum to 12.000000
# Bird 7's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 8's % time at bower is 0.667452
# Bird 8's % time marauding is 0.033707
# Bird 8's % time foraging is 0.298840
# Bird 8's % time repairing bower is 0.000000
# Bird 8's separate accs sum to 12.000000
# Bird 8's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 9's % time at bower is 0.690096
# Bird 9's % time marauding is 0.037022
# Bird 9's % time foraging is 0.272883
# Bird 9's % time repairing bower is 0.000000
# Bird 9's separate accs sum to 12.000000
# Bird 9's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 10's % time at bower is 0.424809
# Bird 10's % time marauding is 0.019290
# Bird 10's % time foraging is 0.389235
# Bird 10's % time repairing bower is 0.166667
# Bird 10's separate accs sum to 12.000000
# Bird 10's allacc is 12.000000
# DOES IT ADD UP: 0.467723
# Bird 11's % time at bower is 0.282064
# Bird 11's % time marauding is 0.000000
# Bird 11's % time foraging is 0.185659
# Bird 11's % time repairing bower is 0.000000
# Bird 11's separate accs sum to 5.612672
# Bird 11's allacc is 5.612672
# DOES IT ADD UP: 1.000000
# Bird 12's % time at bower is 0.602369
# Bird 12's % time marauding is 0.000000
# Bird 12's % time foraging is 0.397631
# Bird 12's % time repairing bower is 0.000000
# Bird 12's separate accs sum to 12.000000
# Bird 12's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 13's % time at bower is 0.550115
# Bird 13's % time marauding is 0.000000
# Bird 13's % time foraging is 0.283218
# Bird 13's % time repairing bower is 0.166667
# Bird 13's separate accs sum to 12.000000
# Bird 13's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 14's % time at bower is 0.529346
# Bird 14's % time marauding is 0.000000
# Bird 14's % time foraging is 0.321228
# Bird 14's % time repairing bower is 0.149426
# Bird 14's separate accs sum to 12.000000
# Bird 14's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 15's % time at bower is 0.579039
# Bird 15's % time marauding is 0.013640
# Bird 15's % time foraging is 0.407320
# Bird 15's % time repairing bower is 0.000000
# Bird 15's separate accs sum to 12.000000
# Bird 15's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 16's % time at bower is 0.556192
# Bird 16's % time marauding is 0.018272
# Bird 16's % time foraging is 0.425536
# Bird 16's % time repairing bower is 0.000000
# Bird 16's separate accs sum to 12.000000
# Bird 16's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 17's % time at bower is 0.646043
# Bird 17's % time marauding is 0.011061
# Bird 17's % time foraging is 0.342896
# Bird 17's % time repairing bower is 0.000000
# Bird 17's separate accs sum to 12.000000
# Bird 17's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 18's % time at bower is 0.488618
# Bird 18's % time marauding is 0.000000
# Bird 18's % time foraging is 0.344715
# Bird 18's % time repairing bower is 0.166667
# Bird 18's separate accs sum to 12.000000
# Bird 18's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 19's % time at bower is 0.373245
# Bird 19's % time marauding is 0.007716
# Bird 19's % time foraging is 0.285706
# Bird 19's % time repairing bower is 0.333333
# Bird 19's separate accs sum to 12.000000
# Bird 19's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 20's % time at bower is 0.676036
# Bird 20's % time marauding is 0.026118
# Bird 20's % time foraging is 0.297846
# Bird 20's % time repairing bower is 0.000000
# Bird 20's separate accs sum to 12.000000
# Bird 20's allacc is 12.000000
# DOES IT ADD UP: 0.028549
# Bird 21's % time at bower is 0.022992
# Bird 21's % time marauding is 0.000000
# Bird 21's % time foraging is 0.005558
# Bird 21's % time repairing bower is 0.000000
# Bird 21's separate accs sum to 0.342593
# Bird 21's allacc is 0.342593
# DOES IT ADD UP: 1.000000
# Bird 22's % time at bower is 0.675366
# Bird 22's % time marauding is 0.024380
# Bird 22's % time foraging is 0.300254
# Bird 22's % time repairing bower is 0.000000
# Bird 22's separate accs sum to 12.000000
# Bird 22's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 23's % time at bower is 0.493417
# Bird 23's % time marauding is 0.000000
# Bird 23's % time foraging is 0.339916
# Bird 23's % time repairing bower is 0.166667
# Bird 23's separate accs sum to 12.000000
# Bird 23's allacc is 12.000000
# DOES IT ADD UP: 0.523307
# Bird 24's % time at bower is 0.336228
# Bird 24's % time marauding is 0.007954
# Bird 24's % time foraging is 0.179125
# Bird 24's % time repairing bower is 0.000000
# Bird 24's separate accs sum to 6.279681
# Bird 24's allacc is 6.279681
# DOES IT ADD UP: 1.000000
# Bird 25's % time at bower is 0.542445
# Bird 25's % time marauding is 0.000000
# Bird 25's % time foraging is 0.124222
# Bird 25's % time repairing bower is 0.333333
# Bird 25's separate accs sum to 12.000000
# Bird 25's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 26's % time at bower is 0.468182
# Bird 26's % time marauding is 0.039252
# Bird 26's % time foraging is 0.325899
# Bird 26's % time repairing bower is 0.166667
# Bird 26's separate accs sum to 12.000000
# Bird 26's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 27's % time at bower is 0.651975
# Bird 27's % time marauding is 0.023318
# Bird 27's % time foraging is 0.324708
# Bird 27's % time repairing bower is 0.000000
# Bird 27's separate accs sum to 12.000000
# Bird 27's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 28's % time at bower is 0.448032
# Bird 28's % time marauding is 0.016505
# Bird 28's % time foraging is 0.358295
# Bird 28's % time repairing bower is 0.177167
# Bird 28's separate accs sum to 12.000000
# Bird 28's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 29's % time at bower is 0.565187
# Bird 29's % time marauding is 0.025237
# Bird 29's % time foraging is 0.409576
# Bird 29's % time repairing bower is 0.000000
# Bird 29's separate accs sum to 12.000000
# Bird 29's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 30's % time at bower is 0.445360
# Bird 30's % time marauding is 0.021974
# Bird 30's % time foraging is 0.333965
# Bird 30's % time repairing bower is 0.198702
# Bird 30's separate accs sum to 12.000000
# Bird 30's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 31's % time at bower is 0.474352
# Bird 31's % time marauding is 0.005787
# Bird 31's % time foraging is 0.353194
# Bird 31's % time repairing bower is 0.166667
# Bird 31's separate accs sum to 12.000000
# Bird 31's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 32's % time at bower is 0.561185
# Bird 32's % time marauding is 0.012411
# Bird 32's % time foraging is 0.426403
# Bird 32's % time repairing bower is 0.000000
# Bird 32's separate accs sum to 12.000000
# Bird 32's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 33's % time at bower is 0.461221
# Bird 33's % time marauding is 0.000000
# Bird 33's % time foraging is 0.372113
# Bird 33's % time repairing bower is 0.166667
# Bird 33's separate accs sum to 12.000000
# Bird 33's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 34's % time at bower is 0.702473
# Bird 34's % time marauding is 0.024934
# Bird 34's % time foraging is 0.272594
# Bird 34's % time repairing bower is 0.000000
# Bird 34's separate accs sum to 12.000000
# Bird 34's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 35's % time at bower is 0.655027
# Bird 35's % time marauding is 0.000000
# Bird 35's % time foraging is 0.344973
# Bird 35's % time repairing bower is 0.000000
# Bird 35's separate accs sum to 12.000000
# Bird 35's allacc is 12.000000
# DOES IT ADD UP: 0.512404
# Bird 36's % time at bower is 0.207823
# Bird 36's % time marauding is 0.001929
# Bird 36's % time foraging is 0.135985
# Bird 36's % time repairing bower is 0.166667
# Bird 36's separate accs sum to 6.148850
# Bird 36's allacc is 6.148850
# DOES IT ADD UP: 1.000000
# Bird 37's % time at bower is 0.505195
# Bird 37's % time marauding is 0.035880
# Bird 37's % time foraging is 0.292259
# Bird 37's % time repairing bower is 0.166667
# Bird 37's separate accs sum to 12.000000
# Bird 37's allacc is 12.000000
# DOES IT ADD UP: 0.505805
# Bird 38's % time at bower is 0.419254
# Bird 38's % time marauding is 0.014433
# Bird 38's % time foraging is 0.072118
# Bird 38's % time repairing bower is 0.000000
# Bird 38's separate accs sum to 6.069665
# Bird 38's allacc is 6.069665
# DOES IT ADD UP: 1.000000
# Bird 39's % time at bower is 0.704032
# Bird 39's % time marauding is 0.018028
# Bird 39's % time foraging is 0.277940
# Bird 39's % time repairing bower is 0.000000
# Bird 39's separate accs sum to 12.000000
# Bird 39's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 40's % time at bower is 0.597726
# Bird 40's % time marauding is 0.024702
# Bird 40's % time foraging is 0.377572
# Bird 40's % time repairing bower is 0.000000
# Bird 40's separate accs sum to 12.000000
# Bird 40's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 41's % time at bower is 0.638328
# Bird 41's % time marauding is 0.021274
# Bird 41's % time foraging is 0.340399
# Bird 41's % time repairing bower is 0.000000
# Bird 41's separate accs sum to 12.000000
# Bird 41's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 42's % time at bower is 0.462361
# Bird 42's % time marauding is 0.022244
# Bird 42's % time foraging is 0.348729
# Bird 42's % time repairing bower is 0.166667
# Bird 42's separate accs sum to 12.000000
# Bird 42's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 43's % time at bower is 0.432320
# Bird 43's % time marauding is 0.016517
# Bird 43's % time foraging is 0.384496
# Bird 43's % time repairing bower is 0.166667
# Bird 43's separate accs sum to 12.000000
# Bird 43's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 44's % time at bower is 0.540184
# Bird 44's % time marauding is 0.004326
# Bird 44's % time foraging is 0.288823
# Bird 44's % time repairing bower is 0.166667
# Bird 44's separate accs sum to 12.000000
# Bird 44's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 45's % time at bower is 0.609162
# Bird 45's % time marauding is 0.010262
# Bird 45's % time foraging is 0.380575
# Bird 45's % time repairing bower is 0.000000
# Bird 45's separate accs sum to 12.000000
# Bird 45's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 46's % time at bower is 0.653956
# Bird 46's % time marauding is 0.012200
# Bird 46's % time foraging is 0.333844
# Bird 46's % time repairing bower is 0.000000
# Bird 46's separate accs sum to 12.000000
# Bird 46's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 47's % time at bower is 0.501345
# Bird 47's % time marauding is 0.027872
# Bird 47's % time foraging is 0.304116
# Bird 47's % time repairing bower is 0.166667
# Bird 47's separate accs sum to 12.000000
# Bird 47's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 48's % time at bower is 0.467732
# Bird 48's % time marauding is 0.029634
# Bird 48's % time foraging is 0.335968
# Bird 48's % time repairing bower is 0.166667
# Bird 48's separate accs sum to 12.000000
# Bird 48's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 49's % time at bower is 0.570250
# Bird 49's % time marauding is 0.025603
# Bird 49's % time foraging is 0.237480
# Bird 49's % time repairing bower is 0.166667
# Bird 49's separate accs sum to 12.000000
# Bird 49's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 50's % time at bower is 0.537949
# Bird 50's % time marauding is 0.030060
# Bird 50's % time foraging is 0.431991
# Bird 50's % time repairing bower is 0.000000
# Bird 50's separate accs sum to 12.000000
# Bird 50's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 51's % time at bower is 0.383450
# Bird 51's % time marauding is 0.011879
# Bird 51's % time foraging is 0.271338
# Bird 51's % time repairing bower is 0.333333
# Bird 51's separate accs sum to 12.000000
# Bird 51's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 52's % time at bower is 0.614460
# Bird 52's % time marauding is 0.009836
# Bird 52's % time foraging is 0.375704
# Bird 52's % time repairing bower is 0.000000
# Bird 52's separate accs sum to 12.000000
# Bird 52's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 53's % time at bower is 0.531213
# Bird 53's % time marauding is 0.025144
# Bird 53's % time foraging is 0.443643
# Bird 53's % time repairing bower is 0.000000
# Bird 53's separate accs sum to 12.000000
# Bird 53's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 54's % time at bower is 0.612630
# Bird 54's % time marauding is 0.018747
# Bird 54's % time foraging is 0.368623
# Bird 54's % time repairing bower is 0.000000
# Bird 54's separate accs sum to 12.000000
# Bird 54's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 55's % time at bower is 0.463917
# Bird 55's % time marauding is 0.042367
# Bird 55's % time foraging is 0.327049
# Bird 55's % time repairing bower is 0.166667
# Bird 55's separate accs sum to 12.000000
# Bird 55's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 56's % time at bower is 0.635410
# Bird 56's % time marauding is 0.026262
# Bird 56's % time foraging is 0.338328
# Bird 56's % time repairing bower is 0.000000
# Bird 56's separate accs sum to 12.000000
# Bird 56's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 57's % time at bower is 0.611884
# Bird 57's % time marauding is 0.017978
# Bird 57's % time foraging is 0.370138
# Bird 57's % time repairing bower is 0.000000
# Bird 57's separate accs sum to 12.000000
# Bird 57's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 58's % time at bower is 0.526530
# Bird 58's % time marauding is 0.000000
# Bird 58's % time foraging is 0.473470
# Bird 58's % time repairing bower is 0.000000
# Bird 58's separate accs sum to 12.000000
# Bird 58's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 59's % time at bower is 0.600328
# Bird 59's % time marauding is 0.033589
# Bird 59's % time foraging is 0.366084
# Bird 59's % time repairing bower is 0.000000
# Bird 59's separate accs sum to 12.000000
# Bird 59's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 60's % time at bower is 0.362499
# Bird 60's % time marauding is 0.000000
# Bird 60's % time foraging is 0.317003
# Bird 60's % time repairing bower is 0.320498
# Bird 60's separate accs sum to 12.000000
# Bird 60's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 61's % time at bower is 0.622461
# Bird 61's % time marauding is 0.052275
# Bird 61's % time foraging is 0.325264
# Bird 61's % time repairing bower is 0.000000
# Bird 61's separate accs sum to 12.000000
# Bird 61's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 62's % time at bower is 0.684829
# Bird 62's % time marauding is 0.006955
# Bird 62's % time foraging is 0.308215
# Bird 62's % time repairing bower is 0.000000
# Bird 62's separate accs sum to 12.000000
# Bird 62's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 63's % time at bower is 0.561020
# Bird 63's % time marauding is 0.000000
# Bird 63's % time foraging is 0.438980
# Bird 63's % time repairing bower is 0.000000
# Bird 63's separate accs sum to 12.000000
# Bird 63's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 64's % time at bower is 0.559460
# Bird 64's % time marauding is 0.016049
# Bird 64's % time foraging is 0.424491
# Bird 64's % time repairing bower is 0.000000
# Bird 64's separate accs sum to 12.000000
# Bird 64's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 65's % time at bower is 0.449003
# Bird 65's % time marauding is 0.009314
# Bird 65's % time foraging is 0.375017
# Bird 65's % time repairing bower is 0.166667
# Bird 65's separate accs sum to 12.000000
# Bird 65's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 66's % time at bower is 0.522423
# Bird 66's % time marauding is 0.009645
# Bird 66's % time foraging is 0.467932
# Bird 66's % time repairing bower is 0.000000
# Bird 66's separate accs sum to 12.000000
# Bird 66's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 67's % time at bower is 0.440736
# Bird 67's % time marauding is 0.021836
# Bird 67's % time foraging is 0.370761
# Bird 67's % time repairing bower is 0.166667
# Bird 67's separate accs sum to 12.000000
# Bird 67's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 68's % time at bower is 0.600757
# Bird 68's % time marauding is 0.023354
# Bird 68's % time foraging is 0.375889
# Bird 68's % time repairing bower is 0.000000
# Bird 68's separate accs sum to 12.000000
# Bird 68's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 69's % time at bower is 0.223328
# Bird 69's % time marauding is 0.000000
# Bird 69's % time foraging is 0.110005
# Bird 69's % time repairing bower is 0.666667
# Bird 69's separate accs sum to 12.000000
# Bird 69's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 70's % time at bower is 0.487424
# Bird 70's % time marauding is 0.019907
# Bird 70's % time foraging is 0.326002
# Bird 70's % time repairing bower is 0.166667
# Bird 70's separate accs sum to 12.000000
# Bird 70's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 71's % time at bower is 0.582389
# Bird 71's % time marauding is 0.048763
# Bird 71's % time foraging is 0.368848
# Bird 71's % time repairing bower is 0.000000
# Bird 71's separate accs sum to 12.000000
# Bird 71's allacc is 12.000000
# DOES IT ADD UP: 0.036033
# Bird 72's % time at bower is 0.021848
# Bird 72's % time marauding is 0.000000
# Bird 72's % time foraging is 0.014184
# Bird 72's % time repairing bower is 0.000000
# Bird 72's separate accs sum to 0.432390
# Bird 72's allacc is 0.432390
# DOES IT ADD UP: 1.000000
# Bird 73's % time at bower is 0.721022
# Bird 73's % time marauding is 0.021974
# Bird 73's % time foraging is 0.257004
# Bird 73's % time repairing bower is 0.000000
# Bird 73's separate accs sum to 12.000000
# Bird 73's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 74's % time at bower is 0.631374
# Bird 74's % time marauding is 0.023469
# Bird 74's % time foraging is 0.345157
# Bird 74's % time repairing bower is 0.000000
# Bird 74's separate accs sum to 12.000000
# Bird 74's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 75's % time at bower is 0.583172
# Bird 75's % time marauding is 0.012706
# Bird 75's % time foraging is 0.404121
# Bird 75's % time repairing bower is 0.000000
# Bird 75's separate accs sum to 12.000000
# Bird 75's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 76's % time at bower is 0.641330
# Bird 76's % time marauding is 0.031072
# Bird 76's % time foraging is 0.327598
# Bird 76's % time repairing bower is 0.000000
# Bird 76's separate accs sum to 12.000000
# Bird 76's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 77's % time at bower is 0.591587
# Bird 77's % time marauding is 0.010388
# Bird 77's % time foraging is 0.398025
# Bird 77's % time repairing bower is 0.000000
# Bird 77's separate accs sum to 12.000000
# Bird 77's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 78's % time at bower is 0.616529
# Bird 78's % time marauding is 0.035282
# Bird 78's % time foraging is 0.348189
# Bird 78's % time repairing bower is 0.000000
# Bird 78's separate accs sum to 12.000000
# Bird 78's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 79's % time at bower is 0.567530
# Bird 79's % time marauding is 0.000000
# Bird 79's % time foraging is 0.432470
# Bird 79's % time repairing bower is 0.000000
# Bird 79's separate accs sum to 12.000000
# Bird 79's allacc is 12.000000
# DOES IT ADD UP: 0.532389
# Bird 80's % time at bower is 0.524385
# Bird 80's % time marauding is 0.000000
# Bird 80's % time foraging is 0.008004
# Bird 80's % time repairing bower is 0.000000
# Bird 80's separate accs sum to 6.388662
# Bird 80's allacc is 6.388662
# DOES IT ADD UP: 1.000000
# Bird 81's % time at bower is 0.600215
# Bird 81's % time marauding is 0.016960
# Bird 81's % time foraging is 0.382825
# Bird 81's % time repairing bower is 0.000000
# Bird 81's separate accs sum to 12.000000
# Bird 81's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 82's % time at bower is 0.594881
# Bird 82's % time marauding is 0.022377
# Bird 82's % time foraging is 0.216076
# Bird 82's % time repairing bower is 0.166667
# Bird 82's separate accs sum to 12.000000
# Bird 82's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 83's % time at bower is 0.579268
# Bird 83's % time marauding is 0.021567
# Bird 83's % time foraging is 0.248042
# Bird 83's % time repairing bower is 0.151122
# Bird 83's separate accs sum to 12.000000
# Bird 83's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 84's % time at bower is 0.508075
# Bird 84's % time marauding is 0.019740
# Bird 84's % time foraging is 0.305518
# Bird 84's % time repairing bower is 0.166667
# Bird 84's separate accs sum to 12.000000
# Bird 84's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 85's % time at bower is 0.589047
# Bird 85's % time marauding is 0.000000
# Bird 85's % time foraging is 0.237670
# Bird 85's % time repairing bower is 0.173283
# Bird 85's separate accs sum to 12.000000
# Bird 85's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 86's % time at bower is 0.690093
# Bird 86's % time marauding is 0.020533
# Bird 86's % time foraging is 0.289374
# Bird 86's % time repairing bower is 0.000000
# Bird 86's separate accs sum to 12.000000
# Bird 86's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 87's % time at bower is 0.637455
# Bird 87's % time marauding is 0.002728
# Bird 87's % time foraging is 0.193151
# Bird 87's % time repairing bower is 0.166667
# Bird 87's separate accs sum to 12.000000
# Bird 87's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 88's % time at bower is 0.445158
# Bird 88's % time marauding is 0.000000
# Bird 88's % time foraging is 0.388176
# Bird 88's % time repairing bower is 0.166667
# Bird 88's separate accs sum to 12.000000
# Bird 88's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 89's % time at bower is 0.581174
# Bird 89's % time marauding is 0.016049
# Bird 89's % time foraging is 0.402776
# Bird 89's % time repairing bower is 0.000000
# Bird 89's separate accs sum to 12.000000
# Bird 89's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 90's % time at bower is 0.645818
# Bird 90's % time marauding is 0.041127
# Bird 90's % time foraging is 0.313055
# Bird 90's % time repairing bower is 0.000000
# Bird 90's separate accs sum to 12.000000
# Bird 90's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 91's % time at bower is 0.549598
# Bird 91's % time marauding is 0.023228
# Bird 91's % time foraging is 0.260507
# Bird 91's % time repairing bower is 0.166667
# Bird 91's separate accs sum to 12.000000
# Bird 91's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 92's % time at bower is 0.583450
# Bird 92's % time marauding is 0.039198
# Bird 92's % time foraging is 0.377352
# Bird 92's % time repairing bower is 0.000000
# Bird 92's separate accs sum to 12.000000
# Bird 92's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 93's % time at bower is 0.607444
# Bird 93's % time marauding is 0.068866
# Bird 93's % time foraging is 0.323691
# Bird 93's % time repairing bower is 0.000000
# Bird 93's separate accs sum to 12.000000
# Bird 93's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 94's % time at bower is 0.505510
# Bird 94's % time marauding is 0.048372
# Bird 94's % time foraging is 0.279452
# Bird 94's % time repairing bower is 0.166667
# Bird 94's separate accs sum to 12.000000
# Bird 94's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 95's % time at bower is 0.584002
# Bird 95's % time marauding is 0.003858
# Bird 95's % time foraging is 0.412140
# Bird 95's % time repairing bower is 0.000000
# Bird 95's separate accs sum to 12.000000
# Bird 95's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 96's % time at bower is 0.628257
# Bird 96's % time marauding is 0.048166
# Bird 96's % time foraging is 0.156910
# Bird 96's % time repairing bower is 0.166667
# Bird 96's separate accs sum to 12.000000
# Bird 96's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 97's % time at bower is 0.549965
# Bird 97's % time marauding is 0.029109
# Bird 97's % time foraging is 0.420926
# Bird 97's % time repairing bower is 0.000000
# Bird 97's separate accs sum to 12.000000
# Bird 97's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 98's % time at bower is 0.440866
# Bird 98's % time marauding is 0.034037
# Bird 98's % time foraging is 0.358431
# Bird 98's % time repairing bower is 0.166667
# Bird 98's separate accs sum to 12.000000
# Bird 98's allacc is 12.000000
# DOES IT ADD UP: 1.000000
# Bird 99's % time at bower is 0.478447
# Bird 99's % time marauding is 0.000000
# Bird 99's % time foraging is 0.382976
# Bird 99's % time repairing bower is 0.138577
# Bird 99's separate accs sum to 12.000000
# Bird 99's allacc is 12.000000

# %%
print(success_times)
#print(len(success_times))
# Out:
# [0.26157407407407407, 0.2663682125274664, 0.27314814814814814, 0.27314814814814814, 0.28273642505493274, 0.28273642505493274, 0.28273642505493274, 0.2847222222222222, 0.28660043588157846, 0.2962962962962963, 0.29910463758239914, 0.30787037037037035, 0.30901642955547204, 0.3123282963788716, 0.312480852287826, 0.3140893424535967, 0.31547285010986553, 0.31748786915330207, 0.31933686093651126, 0.3194444444444444, 0.3201909155352544, 0.3204023441006738, 0.3204023441006738, 0.3221767127025439, 0.3276412492187427, 0.3310185185185185, 0.33346183508018495, 0.33346183508018495, 0.3344972578674279, 0.3380272138363888, 0.34331316838308507, 0.3434917503525876, 0.34805712910879144, 0.34820927516479827, 0.34956394985003036, 0.35472948122153997, 0.3555915002965007, 0.35670769047792694, 0.35670769047792694, 0.35670769047792694, 0.36071067011112534, 0.36574074074074076, 0.3664872118315507, 0.36669864039697014, 0.3668867999258424, 0.36818405730240716, 0.3714972818432981, 0.3720768804085982, 0.37326714745223244, 0.37511863050817884, 0.3804573417188331, 0.3916972301749917, 0.3936830273422812, 0.3960158924289804, 0.3973111059927038, 0.4050419344004888, 0.41030777159641885, 0.4111030842989276, 0.41238410495644684, 0.4153400843262273, 0.41649897165016236, 0.4175253709409528, 0.4231654961824083, 0.42406863050548804, 0.4361430848414146, 0.4473351184944504, 0.45245255547264657, 0.45418057373555504, 0.45445119230718956, 0.45900648906612046, 0.45941399004205874, 0.4617175022360344, 0.4637978698495322, 0.47146765041948396, 0.4761457771909514, 0.48053432237018395, 0.48190044309820435, 0.4826854719666684, 0.5073200784463265, 0.5130039774810649, 0.5154458918633973, 0.523369526048975, 0.5270774179267594, 0.5332522605478427, 0.5544369400409079, 0.5555746626260549, 0.5665558705203381, 0.5669616766092785, 0.5690324247606966, 0.57080370272171, 0.5768535589760856, 0.5776620416936241, 0.581196621650443, 0.5856102193156287, 0.5903828423652446, 0.6056058855042696, 0.6083465482543411, 0.6099330354333274, 0.6221532862728032, 0.6739110529032435, 0.6791820472404326, 0.6803528234023888, 0.7020445581803512, 0.7022519619650788, 0.7267086720001563, 0.7330009967969393, 0.7348670077497343, 1.5014131293462627, 1.5214512830163731, 1.578541829586987, 1.638870339851661, 1.6786862890630885, 1.7072587983142604, 1.7280459531250696, 1.7339901273794807, 1.7347411071199104, 1.748102759104632, 1.7909006070356914, 1.8015117813578554, 1.8748524398555269, 1.8790476128782854, 1.9247815302288354, 1.952840186486944, 1.9549883711885143, 1.9703078810183552, 1.9815456128654574, 1.9932028896026075, 2.008461494994087, 2.0449257533948413, 2.1529107050610543, 2.2154610290616157, 2.2662268115093225, 2.308173839182441, 2.3427668596942897, 2.36487473477421, 2.4219334635003444, 2.433840546075695, 2.4376285617704228, 2.5170612433175155, 2.591060077929782, 2.611071415717568, 2.654336855240744, 2.6677064411352847, 2.6759486438329314, 2.685881482849053, 2.722504102844526, 2.772502963969019, 2.7813712259402283, 2.813097575003844, 2.871434366906321, 2.9018423143939795, 2.9551856355440007, 2.970625170691927, 3.0124900456277093, 3.022165825652115, 3.035824906333115, 3.054016363008943, 3.0632232213060866, 3.076447760544725, 3.125437679389557, 3.1344248857211414, 3.1835856618646035, 3.1951345960856092, 3.217000349013083, 3.2522492289470333, 3.2651129883782826, 3.301910836077727, 3.3320565552758468, 3.3777203171944548, 3.3905655345185965, 3.4562761451850297, 3.4685689448296304, 3.471079345174159, 3.478025460464096, 3.5041804998303334, 3.508252490895925, 3.517840953709888, 3.5793200771842986, 3.586110835457113, 3.6389324559620086, 3.6721195649752447, 3.6739524171909532, 3.691410536756968, 3.712214586375754, 3.749585333660353, 3.750670713745937, 3.7511887753540964, 3.751433053615656, 3.7758263182079363, 3.8203671536564845, 3.828022357124915, 3.866188985392568, 3.9274954190750786, 3.9541736393911613, 3.9554909884977025, 3.989644885201095, 4.029219119495436, 4.056874352303046, 4.088643465771488, 4.093002526035024, 4.152 ...

# %%
#print(len(discards))
#print(discards)

# %%
#print(sims_fitness_states)
avsfs=numpy.mean(sims_fitness_states, 0)
sfs=avsfs.reshape(10,10)
print(sfs) #this is spatial
# Out:
# [[2.88 3.19 2.91 2.94 3.07 2.96 2.98 2.96 3.13 3.01]
#  [2.95 2.84 2.79 3.25 2.88 2.91 3.28 2.94 3.03 3.1 ]
#  [3.1  3.12 2.9  2.96 2.76 3.2  3.37 3.07 3.03 2.85]
#  [2.81 2.77 2.99 2.88 3.17 3.11 3.17 2.83 3.11 3.3 ]
#  [2.94 2.91 2.98 3.04 3.05 2.65 3.13 2.93 2.88 3.12]
#  [3.25 3.05 2.97 2.8  3.09 2.69 2.99 3.12 3.22 3.05]
#  [2.95 2.97 2.81 2.86 3.08 2.71 3.11 2.94 3.22 3.1 ]
#  [2.88 2.91 2.81 3.13 3.17 3.2  2.78 3.04 2.92 3.11]
#  [3.04 3.03 3.   2.99 3.13 3.25 2.87 2.88 3.02 2.91]
#  [2.96 2.92 2.88 3.03 3.12 2.93 3.06 2.86 2.9  3.11]]
# array([[-0.12,  0.19, -0.09, -0.06,  0.07, -0.04, -0.02, -0.04,  0.13,
#          0.01],
#        [-0.05, -0.16, -0.21,  0.25, -0.12, -0.09,  0.28, -0.06,  0.03,
#          0.1 ],
#        [ 0.1 ,  0.12, -0.1 , -0.04, -0.24,  0.2 ,  0.37,  0.07,  0.03,
#         -0.15],
#        [-0.19, -0.23, -0.01, -0.12,  0.17,  0.11,  0.17, -0.17,  0.11,
#          0.3 ],
#        [-0.06, -0.09, -0.02,  0.04,  0.05, -0.35,  0.13, -0.07, -0.12,
#          0.12],
#        [ 0.25,  0.05, -0.03, -0.2 ,  0.09, -0.31, -0.01,  0.12,  0.22,
#          0.05],
#        [-0.05, -0.03, -0.19, -0.14,  0.08, -0.29,  0.11, -0.06,  0.22,
#          0.1 ],
#        [-0.12, -0.09, -0.19,  0.13,  0.17,  0.2 , -0.22,  0.04, -0.08,
#          0.11],
#        [ 0.04,  0.03,  0.  , -0.01,  0.13,  0.25, -0.13, -0.12,  0.02,
#         -0.09],
#        [-0.04, -0.08, -0.12,  0.03,  0.12, -0.07,  0.06, -0.14, -0.1 ,
#          0.11]])

# %%
#sd/mean
